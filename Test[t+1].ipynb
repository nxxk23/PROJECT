# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/PROJECT/blob/main/Test%5Bt%2B1%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
hemo = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Hemodialysis.csv', encoding='latin1')
hemo.shape
# Out:
# (149987, 5)

# %%
import pandas as pd
lab = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Lab.csv')
lab.shape
# Out:
# (21641523, 11)

# %%
patient_uid_list = hemo['PatientUID'].unique().tolist()
lab = lab[~lab['PatientUID'].isin(patient_uid_list)]
lab.shape
# Out:
# (17728574, 11)

# %%
result_item_names = ['CREATININE, 32202']
cr = lab[lab['ResultItemName'].isin(result_item_names)]
labCR = cr[['LabNo','PatientUID', 'PatientVisitUID', 'ResultItemName', 'ResultValue', 'CWhen']]
labCR
# Out:
#           LabNo  PatientUID  PatientVisitUID     ResultItemName ResultValue  \
# 8             1        2299          2024049  CREATININE, 32202         0.9
# 34            1        2299          2381054  CREATININE, 32202         0.9
# 82            1        2299          2480434  CREATININE, 32202         0.9
# 130           1        2299          2757326  CREATININE, 32202         0.8
# 139           1        2299          2926077  CREATININE, 32202         0.7
# ...         ...         ...              ...                ...         ...
# 21628048    159      925649          3617725  CREATININE, 32202        1.11
# 21628296    160      925649          3617725  CREATININE, 32202        1.18
# 21628537    161      925649          3617725  CREATININE, 32202        1.32
# 21628774    162      925649          3617725  CREATININE, 32202        1.38
# 21629005    163      925649          3617725  CREATININE, 32202        1.37
#
#                             CWhen
# 8         2558-02-19 10:32:20.233
# 34        2558-07-17 11:28:05.687
# 82        2558-08-27 09:24:47.420
# 130       2558-12-15 10:15:27.313
# 139       2559-02-18 11:50:52.580
# ...                           ...
# 21628048  2560-04-17 08:54:35.740
# 21628296  2560-04-19 08:41:45.060
# 21628537  2560-04-21 08:47:03.167
# 21628774  2560-04-24 08:59:53.310
# 21629005  2560-04-26 11:02:13.990
#
# [492979 rows x 6 columns]

# %%
result_item_names = ['eGFR(CKD-EPI) age >=18']
eGFR = lab[lab['ResultItemName'].isin(result_item_names)]
labeGFR = eGFR[['LabNo','PatientUID', 'PatientVisitUID', 'ResultItemName', 'ResultValue', 'CWhen']]
labeGFR
# Out:
#           LabNo  PatientUID  PatientVisitUID          ResultItemName  \
# 248           1        2299          3386255  eGFR(CKD-EPI) age >=18
# 255           1        2299          3640924  eGFR(CKD-EPI) age >=18
# 271           1        2299          4020970  eGFR(CKD-EPI) age >=18
# 286           1        2299          4286612  eGFR(CKD-EPI) age >=18
# 331           1        2299          4546471  eGFR(CKD-EPI) age >=18
# ...         ...         ...              ...                     ...
# 21628049    159      925649          3617725  eGFR(CKD-EPI) age >=18
# 21628297    160      925649          3617725  eGFR(CKD-EPI) age >=18
# 21628538    161      925649          3617725  eGFR(CKD-EPI) age >=18
# 21628775    162      925649          3617725  eGFR(CKD-EPI) age >=18
# 21629006    163      925649          3617725  eGFR(CKD-EPI) age >=18
#
#          ResultValue                    CWhen
# 248             71.7  2559-08-15 09:51:54.913
# 255             66.8  2559-11-11 09:40:06.053
# 271            67.20  2560-03-31 10:18:54.363
# 286            69.20  2560-07-05 10:40:40.763
# 331            63.60  2560-10-03 09:19:54.710
# ...              ...                      ...
# 21628049       77.60  2560-04-17 08:54:35.740
# 21628297       72.00  2560-04-19 08:41:45.060
# 21628538       62.90  2560-04-21 08:47:03.167
# 21628775       59.60  2560-04-24 08:59:53.310
# 21629006       60.10  2560-04-26 11:02:13.990
#
# [435224 rows x 6 columns]

# %%
CR = pd.pivot_table(labCR, index=['PatientUID', 'PatientVisitUID'], values=['ResultItemName', 'ResultValue', 'CWhen'], aggfunc='first')
CR
# Out:
#                                               CWhen     ResultItemName  \
# PatientUID PatientVisitUID
# 2299       2024049          2558-02-19 10:32:20.233  CREATININE, 32202
#            2381054          2558-07-17 11:28:05.687  CREATININE, 32202
#            2480434          2558-08-27 09:24:47.420  CREATININE, 32202
#            2757326          2558-12-15 10:15:27.313  CREATININE, 32202
#            2926077          2559-02-18 11:50:52.580  CREATININE, 32202
# ...                                             ...                ...
# 3432056    10312896         2566-01-30 16:16:45.013  CREATININE, 32202
#            10408954         2566-02-24 21:05:12.747  CREATININE, 32202
#            10573233         2566-04-10 09:51:32.587  CREATININE, 32202
# 3437526    10191122         2565-12-26 09:29:11.307  CREATININE, 32202
#            10541118         2566-03-30 18:44:40.160  CREATININE, 32202
#
#                            ResultValue
# PatientUID PatientVisitUID
# 2299       2024049                 0.9
#            2381054                 0.9
#            2480434                 0.9
#            2757326                 0.8
#            2926077                 0.7
# ...                                ...
# 3432056    10312896               0.80
#            10408954               0.84
#            10573233               1.19
# 3437526    10191122               1.31
#            10541118               1.29
#
# [365628 rows x 3 columns]

# %%
eGFR = pd.pivot_table(labeGFR, index=['PatientUID', 'PatientVisitUID'], values=['ResultItemName', 'ResultValue', 'CWhen'], aggfunc='first')
eGFR
# Out:
#                                               CWhen          ResultItemName  \
# PatientUID PatientVisitUID
# 2299       3386255          2559-08-15 09:51:54.913  eGFR(CKD-EPI) age >=18
#            3640924          2559-11-11 09:40:06.053  eGFR(CKD-EPI) age >=18
#            4020970          2560-03-31 10:18:54.363  eGFR(CKD-EPI) age >=18
#            4286612          2560-07-05 10:40:40.763  eGFR(CKD-EPI) age >=18
#            4546471          2560-10-03 09:19:54.710  eGFR(CKD-EPI) age >=18
# ...                                             ...                     ...
# 3432056    10312896         2566-01-30 16:16:45.013  eGFR(CKD-EPI) age >=18
#            10408954         2566-02-24 21:05:12.747  eGFR(CKD-EPI) age >=18
#            10573233         2566-04-10 09:51:32.587  eGFR(CKD-EPI) age >=18
# 3437526    10191122         2565-12-26 09:29:11.307  eGFR(CKD-EPI) age >=18
#            10541118         2566-03-30 18:44:40.160  eGFR(CKD-EPI) age >=18
#
#                            ResultValue
# PatientUID PatientVisitUID
# 2299       3386255                71.7
#            3640924                66.8
#            4020970               67.20
#            4286612               69.20
#            4546471               63.60
# ...                                ...
# 3432056    10312896              72.86
#            10408954              68.69
#            10573233              45.08
# 3437526    10191122              55.94
#            10541118              56.99
#
# [318686 rows x 3 columns]

# %%
import pandas as pd

df = pd.DataFrame(CR)

# Splitting the 'time' column into separate columns
df[['date', 'timestamp']] = df['CWhen'].str.split(' ', expand=True)
df[['year', 'month', 'day']] = df['date'].str.split('-', expand=True)
df[['hour', 'minute', 'second']] = df['timestamp'].str.split(':', expand=True)
df[['second', 'nanosecond']] = df['second'].str.split('.', expand=True)

# Convert year column from BE to AD
df['year'] = df['year'].astype(int) - 543

# Combine columns into a datetime column
df['date'] = pd.to_datetime(df[['year', 'month', 'day',]])
# Convert timestamp to Timedelta
df['timestamp'] = pd.to_timedelta(df['timestamp'])

# Convert date to datetime
df['date'] = pd.to_datetime(df['date'])

# Merge timestamp and date columns
df['datetime'] = df['date'] + df['timestamp']

CR1 = df.sort_values(by=['PatientUID', 'datetime'])

# %%
import pandas as pd

df1 = pd.DataFrame(eGFR)

# Splitting the 'time' column into separate columns
df1[['date', 'timestamp']] = df1['CWhen'].str.split(' ', expand=True)
df1[['year', 'month', 'day']] = df1['date'].str.split('-', expand=True)
df1[['hour', 'minute', 'second']] = df1['timestamp'].str.split(':', expand=True)
df1[['second', 'nanosecond']] = df1['second'].str.split('.', expand=True)

# Convert year column from BE to AD
df1['year'] = df1['year'].astype(int) - 543

# Combine columns into a datetime column
df1['date'] = pd.to_datetime(df1[['year', 'month', 'day',]])
# Convert timestamp to Timedelta
df1['timestamp'] = pd.to_timedelta(df1['timestamp'])

# Convert date to datetime
df1['date'] = pd.to_datetime(df1['date'])

# Merge timestamp and date columns
df1['datetime'] = df1['date'] + df1['timestamp']

eGFR1 = df1.sort_values(by=['PatientUID', 'datetime'])

# %%
eGFR1 = eGFR1[['CWhen','ResultItemName','ResultValue','datetime']]
CR1 = CR1[['CWhen','ResultItemName','ResultValue','datetime']]

# %%
CR1
# Out:
#                                               CWhen     ResultItemName  \
# PatientUID PatientVisitUID
# 2299       2024049          2558-02-19 10:32:20.233  CREATININE, 32202
#            2381054          2558-07-17 11:28:05.687  CREATININE, 32202
#            2480434          2558-08-27 09:24:47.420  CREATININE, 32202
#            2757326          2558-12-15 10:15:27.313  CREATININE, 32202
#            2926077          2559-02-18 11:50:52.580  CREATININE, 32202
# ...                                             ...                ...
# 3432056    10312896         2566-01-30 16:16:45.013  CREATININE, 32202
#            10408954         2566-02-24 21:05:12.747  CREATININE, 32202
#            10573233         2566-04-10 09:51:32.587  CREATININE, 32202
# 3437526    10191122         2565-12-26 09:29:11.307  CREATININE, 32202
#            10541118         2566-03-30 18:44:40.160  CREATININE, 32202
#
#                            ResultValue                datetime
# PatientUID PatientVisitUID
# 2299       2024049                 0.9 2015-02-19 10:32:20.233
#            2381054                 0.9 2015-07-17 11:28:05.687
#            2480434                 0.9 2015-08-27 09:24:47.420
#            2757326                 0.8 2015-12-15 10:15:27.313
#            2926077                 0.7 2016-02-18 11:50:52.580
# ...                                ...                     ...
# 3432056    10312896               0.80 2023-01-30 16:16:45.013
#            10408954               0.84 2023-02-24 21:05:12.747
#            10573233               1.19 2023-04-10 09:51:32.587
# 3437526    10191122               1.31 2022-12-26 09:29:11.307
#            10541118               1.29 2023-03-30 18:44:40.160
#
# [365628 rows x 4 columns]

# %%
eGFR1
# Out:
#                                               CWhen          ResultItemName  \
# PatientUID PatientVisitUID
# 2299       3386255          2559-08-15 09:51:54.913  eGFR(CKD-EPI) age >=18
#            3640924          2559-11-11 09:40:06.053  eGFR(CKD-EPI) age >=18
#            4020970          2560-03-31 10:18:54.363  eGFR(CKD-EPI) age >=18
#            4286612          2560-07-05 10:40:40.763  eGFR(CKD-EPI) age >=18
#            4546471          2560-10-03 09:19:54.710  eGFR(CKD-EPI) age >=18
# ...                                             ...                     ...
# 3432056    10312896         2566-01-30 16:16:45.013  eGFR(CKD-EPI) age >=18
#            10408954         2566-02-24 21:05:12.747  eGFR(CKD-EPI) age >=18
#            10573233         2566-04-10 09:51:32.587  eGFR(CKD-EPI) age >=18
# 3437526    10191122         2565-12-26 09:29:11.307  eGFR(CKD-EPI) age >=18
#            10541118         2566-03-30 18:44:40.160  eGFR(CKD-EPI) age >=18
#
#                            ResultValue                datetime
# PatientUID PatientVisitUID
# 2299       3386255                71.7 2016-08-15 09:51:54.913
#            3640924                66.8 2016-11-11 09:40:06.053
#            4020970               67.20 2017-03-31 10:18:54.363
#            4286612               69.20 2017-07-05 10:40:40.763
#            4546471               63.60 2017-10-03 09:19:54.710
# ...                                ...                     ...
# 3432056    10312896              72.86 2023-01-30 16:16:45.013
#            10408954              68.69 2023-02-24 21:05:12.747
#            10573233              45.08 2023-04-10 09:51:32.587
# 3437526    10191122              55.94 2022-12-26 09:29:11.307
#            10541118              56.99 2023-03-30 18:44:40.160
#
# [318686 rows x 4 columns]

# %%
CR1_reset = CR1.reset_index()
eGFR1_reset = eGFR1.reset_index()

# %%
eGFR1_reset
# Out:
#         PatientUID  PatientVisitUID                    CWhen  \
# 0             2299          3386255  2559-08-15 09:51:54.913
# 1             2299          3640924  2559-11-11 09:40:06.053
# 2             2299          4020970  2560-03-31 10:18:54.363
# 3             2299          4286612  2560-07-05 10:40:40.763
# 4             2299          4546471  2560-10-03 09:19:54.710
# ...            ...              ...                      ...
# 318681     3432056         10312896  2566-01-30 16:16:45.013
# 318682     3432056         10408954  2566-02-24 21:05:12.747
# 318683     3432056         10573233  2566-04-10 09:51:32.587
# 318684     3437526         10191122  2565-12-26 09:29:11.307
# 318685     3437526         10541118  2566-03-30 18:44:40.160
#
#                 ResultItemName ResultValue                datetime
# 0       eGFR(CKD-EPI) age >=18        71.7 2016-08-15 09:51:54.913
# 1       eGFR(CKD-EPI) age >=18        66.8 2016-11-11 09:40:06.053
# 2       eGFR(CKD-EPI) age >=18       67.20 2017-03-31 10:18:54.363
# 3       eGFR(CKD-EPI) age >=18       69.20 2017-07-05 10:40:40.763
# 4       eGFR(CKD-EPI) age >=18       63.60 2017-10-03 09:19:54.710
# ...                        ...         ...                     ...
# 318681  eGFR(CKD-EPI) age >=18       72.86 2023-01-30 16:16:45.013
# 318682  eGFR(CKD-EPI) age >=18       68.69 2023-02-24 21:05:12.747
# 318683  eGFR(CKD-EPI) age >=18       45.08 2023-04-10 09:51:32.587
# 318684  eGFR(CKD-EPI) age >=18       55.94 2022-12-26 09:29:11.307
# 318685  eGFR(CKD-EPI) age >=18       56.99 2023-03-30 18:44:40.160
#
# [318686 rows x 6 columns]

# %%
import pandas as pd

validVisitID_list = []
nextVisitInfo_list = []

for patientID, patient_df in eGFR1_reset.groupby('PatientUID'):
    validVisitID = [patient_df.iloc[0]['PatientVisitUID']]
    visitBefore = patient_df.iloc[0]['datetime']

    for _, row in patient_df.iloc[1:].iterrows():
        visitNow = row['datetime']

        if (visitNow - visitBefore).days >= 365:
            validVisitID.append(row['PatientVisitUID'])
            visitBefore = visitNow

    validVisitID_list.extend(validVisitID)

    for validID in validVisitID:
        next_visit_row = patient_df[patient_df['PatientVisitUID'] == validID].index + 1
        nextVisitInfo_list.extend(next_visit_row.tolist())  # Flatten the list

# Step 4: Filter the DataFrame based on the validVisitID_list
visit_t = eGFR1_reset[eGFR1_reset['PatientVisitUID'].isin(validVisitID_list)]

# Create DataFrame for next visit information using indices
visit_t1 = eGFR1_reset.iloc[nextVisitInfo_list]

# %%
visit_t
# Out:
#         PatientUID  PatientVisitUID                    CWhen  \
# 0             2299          3386255  2559-08-15 09:51:54.913
# 4             2299          4546471  2560-10-03 09:19:54.710
# 10            2299          5812902  2561-12-12 09:18:49.913
# 15            2299          6947220  2562-12-19 09:51:24.427
# 23            2299          8186767  2564-03-04 10:01:42.113
# ...            ...              ...                      ...
# 318672     3421578         10151787  2565-12-14 11:30:53.310
# 318674     3426284         10105952  2565-11-29 10:47:37.917
# 318676     3431501         10144649  2565-12-13 13:42:48.510
# 318678     3432056         10154545  2565-12-15 09:48:31.117
# 318684     3437526         10191122  2565-12-26 09:29:11.307
#
#                 ResultItemName ResultValue                datetime
# 0       eGFR(CKD-EPI) age >=18        71.7 2016-08-15 09:51:54.913
# 4       eGFR(CKD-EPI) age >=18       63.60 2017-10-03 09:19:54.710
# 10      eGFR(CKD-EPI) age >=18       70.20 2018-12-12 09:18:49.913
# 15      eGFR(CKD-EPI) age >=18       64.02 2019-12-19 09:51:24.427
# 23      eGFR(CKD-EPI) age >=18       48.54 2021-03-04 10:01:42.113
# ...                        ...         ...                     ...
# 318672  eGFR(CKD-EPI) age >=18       47.44 2022-12-14 11:30:53.310
# 318674  eGFR(CKD-EPI) age >=18       27.88 2022-11-29 10:47:37.917
# 318676  eGFR(CKD-EPI) age >=18       54.65 2022-12-13 13:42:48.510
# 318678  eGFR(CKD-EPI) age >=18       70.18 2022-12-15 09:48:31.117
# 318684  eGFR(CKD-EPI) age >=18       55.94 2022-12-26 09:29:11.307
#
# [73592 rows x 6 columns]

# %%
visit_t1
# Out:
#         PatientUID  PatientVisitUID                    CWhen  \
# 1             2299          3640924  2559-11-11 09:40:06.053
# 5             2299          4801938  2561-01-04 09:03:28.847
# 11            2299          6082911  2562-03-13 09:13:31.170
# 16            2299          7052512  2563-01-23 08:50:11.863
# 24            2299          8474628  2564-06-21 08:06:49.077
# ...            ...              ...                      ...
# 318673     3421578         10475532  2566-03-14 12:22:38.490
# 318675     3426284         10458792  2566-03-09 15:18:23.807
# 318677     3431501         10527730  2566-03-28 07:41:23.647
# 318679     3432056         10235244  2566-01-09 12:31:53.220
# 318685     3437526         10541118  2566-03-30 18:44:40.160
#
#                 ResultItemName ResultValue                datetime
# 1       eGFR(CKD-EPI) age >=18        66.8 2016-11-11 09:40:06.053
# 5       eGFR(CKD-EPI) age >=18       58.40 2018-01-04 09:03:28.847
# 11      eGFR(CKD-EPI) age >=18       73.50 2019-03-13 09:13:31.170
# 16      eGFR(CKD-EPI) age >=18       64.92 2020-01-23 08:50:11.863
# 24      eGFR(CKD-EPI) age >=18       55.14 2021-06-21 08:06:49.077
# ...                        ...         ...                     ...
# 318673  eGFR(CKD-EPI) age >=18       49.07 2023-03-14 12:22:38.490
# 318675  eGFR(CKD-EPI) age >=18       27.69 2023-03-09 15:18:23.807
# 318677  eGFR(CKD-EPI) age >=18       44.30 2023-03-28 07:41:23.647
# 318679  eGFR(CKD-EPI) age >=18       48.51 2023-01-09 12:31:53.220
# 318685  eGFR(CKD-EPI) age >=18       56.99 2023-03-30 18:44:40.160
#
# [73592 rows x 6 columns]

# %%
visit_t['TimeDiff'] = visit_t.groupby('PatientUID')['datetime'].diff().dt.days / 365
visit_t['ResultValue'] = pd.to_numeric(visit_t['ResultValue'], errors='coerce')
visit_t['TimeDiff'] = pd.to_numeric(visit_t['TimeDiff'], errors='coerce')
list_of_slopes = [(visit_t['ResultValue'].iloc[i+1] - visit_t['ResultValue'].iloc[i]) / visit_t['TimeDiff'].iloc[i+1] for i in range(len(visit_t)-1)]
visit_t['Slopes'] = [None] + list_of_slopes
# Out:
# <ipython-input-19-55d6768db90b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visit_t['TimeDiff'] = visit_t.groupby('PatientUID')['datetime'].diff().dt.days / 365
# <ipython-input-19-55d6768db90b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visit_t['ResultValue'] = pd.to_numeric(visit_t['ResultValue'], errors='coerce')
# <ipython-input-19-55d6768db90b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visit_t['TimeDiff'] = pd.to_numeric(visit_t['TimeDiff'], errors='coerce')
# <ipython-input-19-55d6768db90b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   visit_t['Slopes'] = [None] + list_of_slopes

# %%
visit_t = visit_t.dropna()
visit_t
# Out:
#         PatientUID  PatientVisitUID                    CWhen  \
# 4             2299          4546471  2560-10-03 09:19:54.710
# 10            2299          5812902  2561-12-12 09:18:49.913
# 15            2299          6947220  2562-12-19 09:51:24.427
# 23            2299          8186767  2564-03-04 10:01:42.113
# 27            2299          9385133  2565-04-21 08:45:54.580
# ...            ...              ...                      ...
# 317522     3319961         10553903  2566-04-04 08:28:58.833
# 317529     3319971         10553916  2566-04-04 08:49:20.047
# 317540     3320048         10572126  2566-04-10 08:36:15.217
# 317556     3320050         10572565  2566-04-10 08:58:57.267
# 317568     3321289         10549658  2566-04-03 09:58:08.837
#
#                 ResultItemName  ResultValue                datetime  TimeDiff  \
# 4       eGFR(CKD-EPI) age >=18        63.60 2017-10-03 09:19:54.710  1.131507
# 10      eGFR(CKD-EPI) age >=18        70.20 2018-12-12 09:18:49.913  1.189041
# 15      eGFR(CKD-EPI) age >=18        64.02 2019-12-19 09:51:24.427  1.019178
# 23      eGFR(CKD-EPI) age >=18        48.54 2021-03-04 10:01:42.113  1.208219
# 27      eGFR(CKD-EPI) age >=18        80.47 2022-04-21 08:45:54.580  1.128767
# ...                        ...          ...                     ...       ...
# 317522  eGFR(CKD-EPI) age >=18        33.68 2023-04-04 08:28:58.833  1.054795
# 317529  eGFR(CKD-EPI) age >=18        26.47 2023-04-04 08:49:20.047  1.054795
# 317540  eGFR(CKD-EPI) age >=18        70.36 2023-04-10 08:36:15.217  1.095890
# 317556  eGFR(CKD-EPI) age >=18        30.69 2023-04-10 08:58:57.267  1.082192
# 317568  eGFR(CKD-EPI) age >=18        63.59 2023-04-03 09:58:08.837  1.049315
#
#            Slopes
# 4       -7.158596
# 10       5.550691
# 15      -6.063710
# 23     -12.812245
# 27      28.287500
# ...           ...
# 317522  -4.256753
# 317529  -0.692078
# 317540   7.217875
# 317556 -32.794557
# 317568 -36.776371
#
# [52620 rows x 8 columns]

# %%
visit_t
# Out:
#         PatientUID  PatientVisitUID                    CWhen  \
# 4             2299          4546471  2560-10-03 09:19:54.710
# 10            2299          5812902  2561-12-12 09:18:49.913
# 15            2299          6947220  2562-12-19 09:51:24.427
# 23            2299          8186767  2564-03-04 10:01:42.113
# 27            2299          9385133  2565-04-21 08:45:54.580
# ...            ...              ...                      ...
# 317522     3319961         10553903  2566-04-04 08:28:58.833
# 317529     3319971         10553916  2566-04-04 08:49:20.047
# 317540     3320048         10572126  2566-04-10 08:36:15.217
# 317556     3320050         10572565  2566-04-10 08:58:57.267
# 317568     3321289         10549658  2566-04-03 09:58:08.837
#
#                 ResultItemName  ResultValue                datetime  TimeDiff  \
# 4       eGFR(CKD-EPI) age >=18        63.60 2017-10-03 09:19:54.710  1.131507
# 10      eGFR(CKD-EPI) age >=18        70.20 2018-12-12 09:18:49.913  1.189041
# 15      eGFR(CKD-EPI) age >=18        64.02 2019-12-19 09:51:24.427  1.019178
# 23      eGFR(CKD-EPI) age >=18        48.54 2021-03-04 10:01:42.113  1.208219
# 27      eGFR(CKD-EPI) age >=18        80.47 2022-04-21 08:45:54.580  1.128767
# ...                        ...          ...                     ...       ...
# 317522  eGFR(CKD-EPI) age >=18        33.68 2023-04-04 08:28:58.833  1.054795
# 317529  eGFR(CKD-EPI) age >=18        26.47 2023-04-04 08:49:20.047  1.054795
# 317540  eGFR(CKD-EPI) age >=18        70.36 2023-04-10 08:36:15.217  1.095890
# 317556  eGFR(CKD-EPI) age >=18        30.69 2023-04-10 08:58:57.267  1.082192
# 317568  eGFR(CKD-EPI) age >=18        63.59 2023-04-03 09:58:08.837  1.049315
#
#            Slopes
# 4       -7.158596
# 10       5.550691
# 15      -6.063710
# 23     -12.812245
# 27      28.287500
# ...           ...
# 317522  -4.256753
# 317529  -0.692078
# 317540   7.217875
# 317556 -32.794557
# 317568 -36.776371
#
# [52620 rows x 8 columns]

# %%
indices_plus_one = visit_t.index + 1
selected = eGFR1_reset.iloc[indices_plus_one]
selected.rename(columns={'PatientVisitUID': 'VisitUID_t1'}, inplace=True)
selected.rename(columns={'PatientUID': 'ID'}, inplace=True)
selected
# Out:
# <ipython-input-52-0d70c5092e56>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected.rename(columns={'PatientVisitUID': 'VisitUID_t1'}, inplace=True)
# <ipython-input-52-0d70c5092e56>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   selected.rename(columns={'PatientUID': 'ID'}, inplace=True)
#              ID  VisitUID_t1                    CWhen          ResultItemName  \
# 5          2299      4801938  2561-01-04 09:03:28.847  eGFR(CKD-EPI) age >=18
# 11         2299      6082911  2562-03-13 09:13:31.170  eGFR(CKD-EPI) age >=18
# 16         2299      7052512  2563-01-23 08:50:11.863  eGFR(CKD-EPI) age >=18
# 24         2299      8474628  2564-06-21 08:06:49.077  eGFR(CKD-EPI) age >=18
# 28         2299      9604695  2565-06-29 08:56:40.153  eGFR(CKD-EPI) age >=18
# ...         ...          ...                      ...                     ...
# 317523  3319971      9270331  2565-03-14 16:19:35.427  eGFR(CKD-EPI) age >=18
# 317530  3320048      9242721  2565-03-05 14:00:54.000  eGFR(CKD-EPI) age >=18
# 317541  3320050      9257281  2565-03-10 11:19:21.603  eGFR(CKD-EPI) age >=18
# 317557  3320161      9243769  2565-03-06 17:55:30.397  eGFR(CKD-EPI) age >=18
# 317569  3321917      9257442  2565-03-10 11:59:17.497  eGFR(CKD-EPI) age >=18
#
#        ResultValue                datetime
# 5            58.40 2018-01-04 09:03:28.847
# 11           73.50 2019-03-13 09:13:31.170
# 16           64.92 2020-01-23 08:50:11.863
# 24           55.14 2021-06-21 08:06:49.077
# 28           76.59 2022-06-29 08:56:40.153
# ...            ...                     ...
# 317523       27.20 2022-03-14 16:19:35.427
# 317530       62.45 2022-03-05 14:00:54.000
# 317541       66.18 2022-03-10 11:19:21.603
# 317557       46.58 2022-03-06 17:55:30.397
# 317569        7.18 2022-03-10 11:59:17.497
#
# [52620 rows x 6 columns]

# %%
columns_to_concat = visit_t[['PatientUID', 'PatientVisitUID']].reset_index()
result_df = pd.concat([columns_to_concat, selected.reset_index()], axis=1)
result_df = result_df[['PatientUID','PatientVisitUID','ID','VisitUID_t1','CWhen','ResultItemName','ResultValue','datetime']]
result_df #ไม่ถูกอะ
# Out:
#        PatientUID  PatientVisitUID       ID  VisitUID_t1  \
# 0            2299          4546471     2299      4801938
# 1            2299          5812902     2299      6082911
# 2            2299          6947220     2299      7052512
# 3            2299          8186767     2299      8474628
# 4            2299          9385133     2299      9604695
# ...           ...              ...      ...          ...
# 52615     3319961         10553903  3319971      9270331
# 52616     3319971         10553916  3320048      9242721
# 52617     3320048         10572126  3320050      9257281
# 52618     3320050         10572565  3320161      9243769
# 52619     3321289         10549658  3321917      9257442
#
#                          CWhen          ResultItemName ResultValue  \
# 0      2561-01-04 09:03:28.847  eGFR(CKD-EPI) age >=18       58.40
# 1      2562-03-13 09:13:31.170  eGFR(CKD-EPI) age >=18       73.50
# 2      2563-01-23 08:50:11.863  eGFR(CKD-EPI) age >=18       64.92
# 3      2564-06-21 08:06:49.077  eGFR(CKD-EPI) age >=18       55.14
# 4      2565-06-29 08:56:40.153  eGFR(CKD-EPI) age >=18       76.59
# ...                        ...                     ...         ...
# 52615  2565-03-14 16:19:35.427  eGFR(CKD-EPI) age >=18       27.20
# 52616  2565-03-05 14:00:54.000  eGFR(CKD-EPI) age >=18       62.45
# 52617  2565-03-10 11:19:21.603  eGFR(CKD-EPI) age >=18       66.18
# 52618  2565-03-06 17:55:30.397  eGFR(CKD-EPI) age >=18       46.58
# 52619  2565-03-10 11:59:17.497  eGFR(CKD-EPI) age >=18        7.18
#
#                      datetime
# 0     2018-01-04 09:03:28.847
# 1     2019-03-13 09:13:31.170
# 2     2020-01-23 08:50:11.863
# 3     2021-06-21 08:06:49.077
# 4     2022-06-29 08:56:40.153
# ...                       ...
# 52615 2022-03-14 16:19:35.427
# 52616 2022-03-05 14:00:54.000
# 52617 2022-03-10 11:19:21.603
# 52618 2022-03-06 17:55:30.397
# 52619 2022-03-10 11:59:17.497
#
# [52620 rows x 8 columns]

# %%
result_item = ['eGFR(CKD-EPI) age >=18','CREATININE, 32202']
pick = t1[t1['ResultItemName'].isin(result_item)]
picked = pick[['LabNo','PatientUID', 'PatientVisitUID', 'ResultItemName', 'ResultValue', 'CWhen']]
picked
# Out:
#           LabNo  PatientUID  PatientVisitUID          ResultItemName  \
# 342           1        2299          4801938       CREATININE, 32202
# 343           1        2299          4801938  eGFR(CKD-EPI) age >=18
# 504           1        2299          6082911       CREATININE, 32202
# 505           1        2299          6082911  eGFR(CKD-EPI) age >=18
# 627           1        2299          7052512       CREATININE, 32202
# ...         ...         ...              ...                     ...
# 21596469    104      822860          5140446  eGFR(CKD-EPI) age >=18
# 21597614    105      822860          5140446       CREATININE, 32202
# 21597615    105      822860          5140446  eGFR(CKD-EPI) age >=18
# 21598698    106      822860          5140446       CREATININE, 32202
# 21598699    106      822860          5140446  eGFR(CKD-EPI) age >=18
#
#          ResultValue                    CWhen
# 342             0.96  2561-01-04 09:03:28.847
# 343            58.40  2561-01-04 09:03:28.847
# 504             0.79  2562-03-13 09:13:31.170
# 505            73.50  2562-03-13 09:13:31.170
# 627             0.87  2563-01-23 08:50:11.863
# ...              ...                      ...
# 21596469       50.00  2561-10-20 07:51:20.613
# 21597614        1.29  2561-10-21 07:49:18.393
# 21597615       46.70  2561-10-21 07:49:18.393
# 21598698        1.22  2561-10-22 07:39:58.133
# 21598699       50.00  2561-10-22 07:39:58.133
#
# [138958 rows x 6 columns]
