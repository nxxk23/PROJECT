# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/PROJECT/blob/main/CountUniqueValues.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ##🗂️Import data: vitalsign

# %%
import pandas as pd
vital = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/vitalsign.csv')
vital.head()
# Out:
#    LabNo  PatientUID  PatientVisitUID       OrderItemName    ResultItemName  \
# 0      1       24513          2140458  Vital Signs Record            Weight
# 1      1       24513          2341133  Vital Signs Record               BMI
# 2      1       24513          2341133  Vital Signs Record        Pulse Rate
# 3      1       24513          2341133  Vital Signs Record  Respiratory Rate
# 4      1       24513          2388152  Vital Signs Record               BMI
#
#   ResultValue                    CWhen
# 0        76.7  2558-04-08 09:57:59.153
# 1       30.76  2558-07-01 09:20:02.617
# 2          98  2558-07-01 09:20:02.617
# 3          20  2558-07-01 09:20:02.617
# 4       30.36  2558-07-22 10:04:54.377

# %% [markdown]
# ### 🔎UniqueValues
# columns: **OrderItemName and ResultItemName** in vitalsign.csv

# %%
# Specify the columns for unique value counting
columns_to_count = ['OrderItemName', 'ResultItemName']

# Count unique values in the specified columns
unique_counts = vital[columns_to_count].value_counts().reset_index()

# %%
unique_counts.columns = ['OrderItemName','ResultItemName', 'Count']
unique_counts
# Out:
#          OrderItemName      ResultItemName    Count
# 0   Vital Signs Record         Systolic BP  1389230
# 1   Vital Signs Record        Diastolic BP  1387866
# 2   Vital Signs Record          Pulse Rate  1326568
# 3   Vital Signs Record    Respiratory Rate  1044964
# 4   Vital Signs Record         Temperature   670561
# 5   Vital Signs Record              Weight   666734
# 6   Vital Signs Record              Height   624585
# 7   Vital Signs Record                 BMI   612300
# 8   Vital Signs Record                 BSA   612014
# 9   Vital Signs Record              O2 Sat   500912
# 10  Vital Signs Record          Pain Score   242681
# 11  Vital Signs Record        MeanPressure   127336
# 12  Vital Signs Record           Waistline     6291
# 13  Vital Signs Record  IrregularHeartBeat     1063
# 14  Vital Signs Record  Head Circumference      284
# 15  Vital Signs Record                6MWT       85
# 16  Vital Signs Record                 Fat       12
# 17  Vital Signs Record  AverageMeasurement       11

# %%
vitalsign_df = pd.DataFrame(unique_counts)
vitalsign_df
# Out:
#          OrderItemName      ResultItemName    Count
# 0   Vital Signs Record         Systolic BP  1389230
# 1   Vital Signs Record        Diastolic BP  1387866
# 2   Vital Signs Record          Pulse Rate  1326568
# 3   Vital Signs Record    Respiratory Rate  1044964
# 4   Vital Signs Record         Temperature   670561
# 5   Vital Signs Record              Weight   666734
# 6   Vital Signs Record              Height   624585
# 7   Vital Signs Record                 BMI   612300
# 8   Vital Signs Record                 BSA   612014
# 9   Vital Signs Record              O2 Sat   500912
# 10  Vital Signs Record          Pain Score   242681
# 11  Vital Signs Record        MeanPressure   127336
# 12  Vital Signs Record           Waistline     6291
# 13  Vital Signs Record  IrregularHeartBeat     1063
# 14  Vital Signs Record  Head Circumference      284
# 15  Vital Signs Record                6MWT       85
# 16  Vital Signs Record                 Fat       12
# 17  Vital Signs Record  AverageMeasurement       11

# %% [markdown]
# ##🗂️Import data: Diagnosis

# %%
import pandas as pd
diagnosis = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/Diagnosis.csv')
diagnosis.head()
# Out:
#    PatientUID  PatientVisitUID ProblemCode  \
# 0       22496                0        K922
# 1       20509                0        R104
# 2        6629                0        K052
# 3       22234                0        E112
# 4       22234                0        N083
#
#                                          ProblemName  \
# 0         Gastrointestinal haemorrhage\, unspecified
# 1               Other and unspecified abdominal pain
# 2                                Acute periodontitis
# 3  Non-insulin-dependent diabetes mellitus type 2...
# 4  Glomerular disorders in diabetes mellitus ( E1...
#
#                                   ProblemDescription  \
# 0   เลือดออกในกระเพาะอาหารและลำไส้ ไม่ระบุรายละเอียด
# 1                 ปวดท้องแบบอื่นและไม่ระบุรายละเอียด
# 2                       โรคปริทันต์อักเสียบเฉียบพลัน
# 3  เบาหวานชนิดที่ไม่ต้องพึ่งอินซูลิน ร่วมกับภาวะแ...
# 4  ความผิดปกติของโกลเมอรูลัสในโรคเบาหวาน (E10-E14...
#
#                             DIAGTYPE                OnsetDttm
# 0  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-05 00:00:00.000
# 1  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-05 00:00:00.000
# 2  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-05 00:00:00.000
# 3  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-07 00:00:00.000
# 4  PRINCIPAL DX (การวินิจฉัยโรคหลัก)  2556-01-07 00:00:00.000

# %% [markdown]
# ### 🔎**UniqueValues**
# columns: **ProblemCode, ProblemName, and (ProblemCode,ProblemName)** in Diagnosis.csv

# %%
diag_code = diagnosis['ProblemCode'].value_counts().reset_index()
diag_code.columns = ['UniqueValue_CODE','Count']
diag_code
# Out:
#       UniqueValue_CODE   Count
# 0            370992007  133314
# 1                  I10   97039
# 2             44054006   76676
# 3              1201005   72796
# 4             59621000   57233
# ...                ...     ...
# 19480         90228003       1
# 19481        174428001       1
# 19482          7407001       1
# 19483         92129006       1
# 19484         95209008       1
#
# [19485 rows x 2 columns]

# %%
diag_name = diagnosis['ProblemName'].value_counts().reset_index()
diag_name.columns = ['UniqueValue_NAME','Count']
diag_name
# Out:
#                              UniqueValue_NAME   Count
# 0                                Dyslipidemia  133313
# 1            Essential (primary) hypertension   97039
# 2                    Type 2 diabetes mellitus   76674
# 3               Benign essential hypertension   72802
# 4                      Essential hypertension   58016
# ...                                       ...     ...
# 18423                         Impacted molars       1
# 18424                        Animal bites NOS       1
# 18425          Control of haemorrhage of nose       1
# 18426  Infective endocarditis of aortic valve       1
# 18427       Plasma cell leukemia in remission       1
#
# [18428 rows x 2 columns]

# %%
# Specify the columns for unique value counting
columns_to_count = ['ProblemCode', 'ProblemName']

# Count unique values in the specified columns
diag_count = diagnosis[columns_to_count].value_counts().reset_index()
diag_count.columns = ['ProblemCode', 'ProblemName', 'Count']
diag_count
# Out:
#       ProblemCode                                       ProblemName   Count
# 0       370992007                                      Dyslipidemia  133313
# 1             I10                  Essential (primary) hypertension   97039
# 2        44054006                          Type 2 diabetes mellitus   76674
# 3         1201005                     Benign essential hypertension   72796
# 4        59621000                            Essential hypertension   57232
# ...           ...                                               ...     ...
# 19634   424648000  Closed fracture of base of fifth metatarsal bone       1
# 19635    42452002                            Thoracic radiculopathy       1
# 19636   424492005                                      Itch of skin       1
# 19637   424408000                         Keratoacanthoma of eyelid       1
# 19638     4208000     Closed multiple fractures of both lower limbs       1
#
# [19639 rows x 3 columns]

# %%
diag_df = pd.DataFrame(diag_count)
diag_df
# Out:
#       ProblemCode                                       ProblemName   Count
# 0       370992007                                      Dyslipidemia  133313
# 1             I10                  Essential (primary) hypertension   97039
# 2        44054006                          Type 2 diabetes mellitus   76674
# 3         1201005                     Benign essential hypertension   72796
# 4        59621000                            Essential hypertension   57232
# ...           ...                                               ...     ...
# 19634   424648000  Closed fracture of base of fifth metatarsal bone       1
# 19635    42452002                            Thoracic radiculopathy       1
# 19636   424492005                                      Itch of skin       1
# 19637   424408000                         Keratoacanthoma of eyelid       1
# 19638     4208000     Closed multiple fractures of both lower limbs       1
#
# [19639 rows x 3 columns]

# %% [markdown]
# ##🗂️Import data: Lab

# %%
import pandas as pd
lab = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/Lab.csv')
lab.head()
# Out:
#    LabNo  PatientUID  PatientVisitUID  \
# 0      1        2299          2024049
# 1      1        2299          2024049
# 2      1        2299          2024049
# 3      1        2299          2024049
# 4      1        2299          2024049
#
#                                     Location RequestItemName  \
# 0              เวชศาสตร์นิวเคลียร์ (OPD)-D15      BMD LUMBAR
# 1  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  ALBUMIN, 32403
# 2  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร   Alkaline Phos
# 3  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร      ALT, 32311
# 4  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร      AST, 32310
#
#      ResultItemName                    CWhen ResultDttm ResultValue Unit  \
# 0  Formatted Result  2558-02-19 16:16:51.423        NaN          FT  NaN
# 1    ALBUMIN, 32403  2558-02-19 10:32:20.907        NaN         4.1  NaN
# 2        ALP, 32309  2558-02-19 10:32:21.610        NaN          44  NaN
# 3        ALT, 32311  2558-02-19 10:32:21.390        NaN          17  NaN
# 4        AST, 32310  2558-02-19 10:32:21.500        NaN          23  NaN
#
#   ReferenceRange
# 0            NaN
# 1      3.8 - 5.4
# 2       42 - 121
# 3         4 - 36
# 4        12 - 32

# %%
lab_location = lab['Location'].value_counts().reset_index()
lab_location.columns = ['Location', 'Location_Count']

lab_result = lab['ResultItemName'].value_counts().reset_index()
lab_result.columns = ['ResultItemName', 'ResultItemName_Count']

lab_request = lab['RequestItemName'].value_counts().reset_index()
lab_request.columns = ['RequestItemName', 'RequestItemName_Count']

columns_to_count = ['Location', 'ResultItemName', 'RequestItemName']

# Count unique values in the specified columns
lab_count = lab[columns_to_count].value_counts().reset_index()
lab_count.columns = ['Location', 'ResultItemName', 'RequestItemName', 'Count']

# %% [markdown]
# ###➕Assignment Added

# %% [markdown]
# ในตาราง Lab.csv ให้ทำตาราง frequency ที่เป็นสามตัวแปร Location, RequestItemName, ResultItemName เป็นการเพิ่มตัวแปร เพราะที่ทำมาก่อนหน้านี้มีแค่สองตัวแปรค่ะ

# %%
lab_count
# Out:
#                                        Location  \
# 0     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 2     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 4     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# ...                                         ...
# 3441                     ห้อง Xray ชั้น 1-D1403
# 3442  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3443  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3444            ห้องปฏิบัติการภาควิชาปรสิตวิทยา
# 3445                           OPD Anest (SPAC)
#
#                                          ResultItemName  \
# 0                                     CREATININE, 32202
# 1                                eGFR(CKD-EPI) age >=18
# 2                                      POTASSIUM, 32103
# 3                                    BICARBONATE, 32105
# 4                                         SODIUM, 32102
# ...                                                 ...
# 3441                                   Formatted Result
# 3442                                          FSH 0 min
# 3443                                         FSH 60 min
# 3444  Concentration technique for parasite (non-stoo...
# 3445                                              BE(B)
#
#                                         RequestItemName   Count
# 0                                            CREATININE  554545
# 1                                            CREATININE  518694
# 2                                             POTASSIUM  496043
# 3                                           BICARBONATE  482723
# 4                                                SODIUM  482123
# ...                                                 ...     ...
# 3441                               HIP (LEFT FROG LEG)        1
# 3442                                          FSH 0 min       1
# 3443                                         FSH 60 min       1
# 3444  Concentration technique for parasite (non-stoo...       1
# 3445                                     BloodGas(POCT)       1
#
# [3446 rows x 4 columns]

# %%
lab_df = pd.DataFrame(lab_count)
lab_df
# Out:
#                                        Location  \
# 0     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 2     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 4     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# ...                                         ...
# 3441                     ห้อง Xray ชั้น 1-D1403
# 3442  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3443  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3444            ห้องปฏิบัติการภาควิชาปรสิตวิทยา
# 3445                           OPD Anest (SPAC)
#
#                                          ResultItemName  \
# 0                                     CREATININE, 32202
# 1                                eGFR(CKD-EPI) age >=18
# 2                                      POTASSIUM, 32103
# 3                                    BICARBONATE, 32105
# 4                                         SODIUM, 32102
# ...                                                 ...
# 3441                                   Formatted Result
# 3442                                          FSH 0 min
# 3443                                         FSH 60 min
# 3444  Concentration technique for parasite (non-stoo...
# 3445                                              BE(B)
#
#                                         RequestItemName   Count
# 0                                            CREATININE  554545
# 1                                            CREATININE  518694
# 2                                             POTASSIUM  496043
# 3                                           BICARBONATE  482723
# 4                                                SODIUM  482123
# ...                                                 ...     ...
# 3441                               HIP (LEFT FROG LEG)        1
# 3442                                          FSH 0 min       1
# 3443                                         FSH 60 min       1
# 3444  Concentration technique for parasite (non-stoo...       1
# 3445                                     BloodGas(POCT)       1
#
# [3446 rows x 4 columns]

# %% [markdown]
# ### 🔎**UniqueValues**
# columns: **Location and ResultItemName** in Lab.csv

# %%
lab_location = lab['Location'].value_counts().reset_index()
lab_location.columns = ['Location','Count']
lab_location
# Out:
#                                         Location     Count
# 0                ห้องปฏิบัติการจุลทรรศน์วินิจฉัย  11033732
# 1      ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร   9919377
# 2           ห้องปฏิบัติการหน่วยจุลชีววิทยาคลินิก    200353
# 3           ห้องปฏิบัติการภูมิคุ้มกันวิทยาคลินิก    190574
# 4                         ห้อง Xray ชั้น 1-D1403    114615
# 5                ห้องปฏิบัติการภาควิชาปรสิตวิทยา     48546
# 6          ห้องปฏิบัติการหน่วยชีวโมเลกุลวินัจฉัย     33513
# 7               ห้องปฏิบัติการภาควิชาจุลชีววิทยา     27910
# 8                ห้องปฏิบัติการภาควิชาพยาธิวิทยา     24011
# 9                  เวชศาสตร์นิวเคลียร์ (OPD)-D15     18160
# 10                  ห้องปฏิบัติการคณะเภสัชศาสตร์     14315
# 11                   ห้องปฏิบัติการคลังเลือดกลาง     13071
# 12  หน่วยทะเบียนกลาง(Test พิเศษ)เวชศาสตร์ชันสูตร      1642
# 13                ห้องปฏิบัติการเภสัชพันธุศาสตร์       951
# 14                            ห้องปฏิบัติการ SEL       430
# 15              ห้องปฏิบัติการภาควิชาอายุรศาสตร์        62
# 16                              OPD Anest (SPAC)        45
# 17               ห้องปฏิบัติการคณะเทคนิคการแพทย์        28
# 18            ห้องปฏิบัติการภาควิชานิติเวชศาสตร์        25
# 19                                OR คลินิก-TH09         6
# 20           ห้องปฏิบัติการเตรียมโลหิตให้ผู้ป่วย         3
# 21            หน่วยโรคไต4จ มูลนิธิจิตตานุเคราะห์         2
# 22              ห้องปฏิบัติการตรวจสอบโลหิตบริจาค         2
# 23                         ห้องปฏิบัติการชีวเคมี         2
# 24                           ขอใบเคลมประกันชีวิต         1

# %%
lab_result = lab['ResultItemName'].value_counts().reset_index()
lab_result.columns = ['ResultItemName','Count']
lab_result
# Out:
#                        ResultItemName   Count
# 0                   CREATININE, 32202  587851
# 1                               WBC    568859
# 2                               RBC    568809
# 3                    POTASSIUM, 32103  520628
# 4              eGFR(CKD-EPI) age >=18  518711
# ...                               ...     ...
# 1548   RQ-PCR for BCR/ABL (p190,p210)       1
# 1549          EBV, qualitative RT-PCR       1
# 1550  Benzodiazepine (screening test)       1
# 1551        PCR for EBV : qualitative       1
# 1552                        Antigen S       1
#
# [1553 rows x 2 columns]

# %%
# Specify the columns for unique value counting
columns_to_count = ['Location', 'ResultItemName']

# Count unique values in the specified columns
lab_count = lab[columns_to_count].value_counts().reset_index()
lab_count.columns = ['Location', 'ResultItemName', 'Count']
lab_count
# Out:
#                                        Location  \
# 0     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1               ห้องปฏิบัติการจุลทรรศน์วินิจฉัย
# 2               ห้องปฏิบัติการจุลทรรศน์วินิจฉัย
# 3     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 4     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# ...                                         ...
# 1842  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1843           ห้องปฏิบัติการภาควิชาจุลชีววิทยา
# 1844      ห้องปฏิบัติการหน่วยชีวโมเลกุลวินัจฉัย
# 1845      ห้องปฏิบัติการหน่วยชีวโมเลกุลวินัจฉัย
# 1846                           OPD Anest (SPAC)
#
#                                ResultItemName   Count
# 0                           CREATININE, 32202  587851
# 1                                       WBC    568852
# 2                                       RBC    568802
# 3                            POTASSIUM, 32103  520628
# 4                      eGFR(CKD-EPI) age >=18  518711
# ...                                       ...     ...
# 1842                                FSH 0 min       1
# 1843                             Consistent         1
# 1844  Phospholipase A2 Receptor Ab (PLA2R Ab)       1
# 1845      Parvo virus B19, qualitative RT-PCR       1
# 1846                                    BE(B)       1
#
# [1847 rows x 3 columns]

# %% [markdown]
# ##🗂️Import data: Prescription

# %%
import pandas as pd
prescription = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/Prescription.csv')
prescription.head()
# Out:
#    PatientUID  PatientVisitUID            DispensedDttm  \
# 0        2299          2024049  2558-02-19 14:48:15.693
# 1        2299          2024049  2558-02-19 14:48:15.693
# 2        2299          2024049  2558-02-19 14:48:15.693
# 3        2299          2024049  2558-02-19 14:48:15.693
# 4        2299          2024049  2558-02-19 14:47:55.953
#
#                        DrugName                    GenericName  Quantity  \
# 0           Folic Acid 5 mg TAB               Folivit tab 5 mg      90.0
# 1         Vitamin B Complex TAB          Vitamin B Complex TAB     180.0
# 2   losartan(Loranta) 50 mg TAB  Loranta film-coated tab 50 mg      90.0
# 3  lorazepam(Anxira) 0.5 mg TAB              Anxira tab 0.5 mg      30.0
# 4              ChalkTAB-1.5 TAB               Chalktab 1500 mg      90.0
#
#                               DrugFrequency  Dosage DosageForm  DrugDuration
# 0        od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB          90.0
# 1  bid pc |วันละ 2 ครั้ง หลังอาหารเช้า เย็น     1.0      1 TAB          90.0
# 2        od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB          90.0
# 3                 hs |วันละ 1 ครั้ง ก่อนนอน     1.0      1 TAB          30.0
# 4        od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB          90.0

# %% [markdown]
# ### **🔎UniqueValues**
# columns: **DrugName, GenericName, and (DrugName,GenericName)** in Prescription.csv

# %% [markdown]
# ###➕Assignment Added

# %% [markdown]
# 2) ในตาราง Prescription.csv ให้ทำตารางรายการยาใหม่ที่ใช้ตัวแปร DrugName และ GenericName แต่ว่าให้มีการเตรียมข้อมูลในไฟล์ใหม่ โดยตัดขนาดยาออกทั้งหมด คือ เลือกแต่คำที่ปรากฏก่อนขนาดยา เช่น
# - hydralazine(Cesoline W) 25 mg TAB เป็น hydralazine(Cesoline W)
# - Cesoline-W film-coated tab 25 mg เป็น Cesoline-W film-coated tab
# - CalTAB-1000 TAB เป็น CalTAB
# - Senolax 7.5 mg TAB เป็น Senolax
# - Ferrous fumarate 200mg TAB เป็น Ferrous fumarate
#
# ซึ่งวิธีการคือจากคำเต็ม ให้สร้างเป็นให้แบ่ง split โดยใช้ sep เป็น space หรือ dash (-) แล้วหาตำแหน่งของคำที่ขึ้นต้นด้วยตัวเลข แล้วเลือกคำทั้งหมดก่อนหน้านั้นมา join กันเป็นชื่อยาใหม่ค่ะ

# %%
prescription = prescription[['DrugName','GenericName']]

# %%
# Function to clean medication names
def clean_medication_name(medication):
    if isinstance(medication, str):
        return medication.split(' ', 1)[0]
    else:
        return medication

# Apply clean_medication_name function to 'DrugName' column
prescription['CleanDrugName'] = prescription['DrugName'].apply(clean_medication_name)
prescription['CleanGenericName'] = prescription['GenericName'].apply(clean_medication_name)

# Print the dataframe with cleaned medication names
print(prescription)
# Out:
#                                                   DrugName  \
# 0                                      Folic Acid 5 mg TAB
# 1                                    Vitamin B Complex TAB
# 2                              losartan(Loranta) 50 mg TAB
# 3                             lorazepam(Anxira) 0.5 mg TAB
# 4                                         ChalkTAB-1.5 TAB
# ...                                                    ...
# 9530447                   Infusion plabottle set (IV.set)
# 9530448                      Normal Saline 0.9% IV 1000 ml
# 9530449                       Normal Saline 0.9% IV 100 ml
# 9530450          Minimun Volume Extension with T connector
# 9530451  Intravenous Disposable Catheter ch.20 ความยาวป...
#
#                            GenericName      CleanDrugName CleanGenericName
# 0                     Folivit tab 5 mg              Folic          Folivit
# 1                Vitamin B Complex TAB            Vitamin          Vitamin
# 2        Loranta film-coated tab 50 mg  losartan(Loranta)          Loranta
# 3                    Anxira tab 0.5 mg  lorazepam(Anxira)           Anxira
# 4                     Chalktab 1500 mg       ChalkTAB-1.5         Chalktab
# ...                                ...                ...              ...
# 9530447                            NaN           Infusion              NaN
# 9530448  Normal Saline 0.9% IV 1000 ml             Normal           Normal
# 9530449   Normal Saline 0.9% IV 100 ml             Normal           Normal
# 9530450                            NaN            Minimun              NaN
# 9530451                            NaN        Intravenous              NaN
#
# [9530452 rows x 4 columns]

# %%
import pandas as pd
# Assuming you have a DataFrame named 'prescription' containing the data
#prescription['New_DrugName'] = prescription['DrugName'].str.replace(r'\s*\d+(\.\d+)?\(mg|g|ml|INJ|TAB)?', '', regex=True)
#unique_drugs = prescription['New_DrugName'].unique()
#unique_drugs_df = pd.DataFrame(unique_drugs, columns=['New_DrugName']).reset_index(drop=True)
#print(unique_drugs_df)

# %%
import pandas as pd
import re

# Assuming you have a DataFrame named 'prescription' containing the data
#prescription['New_GenericName'] = prescription['GenericName'].str.replace(r'\d+(\.\d+)?\s*(mg|g|ml| TAB| tab|INJ|u/mL|iu+/ml INJ| / INJ)?', '', regex=True, flags=re.I)
#unique_drugs2 = prescription['New_GenericName'].unique()
#unique_drugs_df2 = pd.DataFrame(unique_drugs2, columns=['New_GenericName']).reset_index(drop=True)
#print(unique_drugs_df2)

# %%
import pandas as pd

# Assuming you have a DataFrame named 'prescription' containing the data
unique_drug_count = prescription['DrugName'].nunique()
unique_generic_count = prescription['GenericName'].nunique()

print("Number of Old drugs:", unique_drug_count)
print("Number of Old generic names:", unique_generic_count)
# Out:
# Number of Old drugs: 8230
# Number of Old generic names: 2326

# %%
unique_drug_count = prescription['CleanDrugName'].nunique()
unique_generic_count = prescription['CleanGenericName'].nunique()

print("Number of New drugs:", unique_drug_count)
print("Number of New generic names:", unique_generic_count)
# Out:
# Number of New drugs: 2809
# Number of New generic names: 1616

# %%
prescription = prescription[['CleanDrugName','CleanGenericName']]

# %%
pre_drug = prescription['CleanDrugName'].value_counts().reset_index()
pre_drug.columns = ['DrugName', 'Count']

pre_generic = prescription['CleanGenericName'].value_counts().reset_index()
pre_generic.columns = ['GenericName', 'Count']

pre_count = prescription.groupby(['CleanDrugName', 'CleanGenericName']).size().reset_index()
pre_count.columns = ['DrugName', 'GenericName', 'Count']

# %%
pre_drug
# Out:
#                                                DrugName   Count
# 0                                               Vitamin  346827
# 1                                                Normal  286490
# 2                                                 Folic  262937
# 3                                        aspirin(Aspent  191145
# 4                                   omeprazole(Miracid)  189804
# ...                                                 ...     ...
# 2804                      อาหารทางการแพทย์สูตรโปรตีนและ       1
# 2805                                              Vopar       1
# 2806                                             Exocin       1
# 2807                                           Pentaxim       1
# 2808  สายสวนเพื่อการขยายหลอดเลือดแดงใหญ่เอออร์ตาด้วย...       1
#
# [2809 rows x 2 columns]

# %%
pre_generic
# Out:
#          GenericName   Count
# 0             Normal  286490
# 1            Folivit  262937
# 2            Vitamin  260465
# 3     aspirin(Aspent  191145
# 4            Miracid  189804
# ...              ...     ...
# 1611           Mist.       1
# 1612          Exocin       1
# 1613        Pentaxim       1
# 1614         Hexaxim       1
# 1615        Adcetris       1
#
# [1616 rows x 2 columns]

# %%
pre_df = pd.DataFrame(pre_count)
pre_df
# Out:
#                          DrugName            GenericName  Count
# 0                              2%                     2%     47
# 1                             3TC                    3TC    801
# 2                             3TC                Lamivir    289
# 3                             3TC             Lamivudine  10751
# 4                            5-FU                   5-FU     19
# ...                           ...                    ...    ...
# 1827  ใบมีดตัดเนื้อเยื่ออ่อนในข้อ  Fluconazole(Fluzoral)      1
# 1828  ใบมีดตัดเนื้อเยื่ออ่อนในข้อ        Furosemide(GPO)      1
# 1829  ใบมีดตัดเนื้อเยื่ออ่อนในข้อ              Potassium      3
# 1830  ใบมีดตัดเนื้อเยื่ออ่อนในข้อ        Rifampicin(GPO)     15
# 1831                   ไดยูโทรแปน              Diutropan   3495
#
# [1832 rows x 3 columns]

# %%
pre_drug = pd.DataFrame(pre_drug)
pre_generic = pd.DataFrame(pre_generic)

# %% [markdown]
# ###   **Excel of Prescription File**

# %%
with pd.ExcelWriter('PrescriptionCount.xlsx') as writer:
    pre_df.to_excel(writer, sheet_name='Prescription')
    pre_drug.to_excel(writer, sheet_name='CleanDrugName')
    pre_generic.to_excel(writer, sheet_name='CleanGenericName')

# %% [markdown]
# ##🗂️Import data: visit

# %%
import pandas as pd
visit = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/Visit.csv')
visit.head()
# Out:
# <ipython-input-34-2fc26b67033e>:2: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   visit = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/Visit.csv')
#    PatientUID  PatientvisitUID   Sex  Age         ENTY NATNL  \
# 0       19319            25325  หญิง   83  Out Patient   ไทย
# 1       83224            25327   ชาย   64  Out Patient   ไทย
# 2      160455            25336   ชาย   86  Out Patient   ไทย
# 3      181216            25338  หญิง   82  Out Patient   ไทย
# 4      568147            25357   ชาย   68  Out Patient   ไทย
#
#                  StartDTTM                  EndDttm Location  \
# 0  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 1  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 2  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 3  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 4  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
#
#   PricipalProblemCode PricipalProblemName
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN

# %% [markdown]
# ### **🔎UniqueValues**
# columns: **PatientUID, PatientvisitUID, Sex, Age, ENTY, NATNL** in Visit.csv

# %%
visit_Sex = visit['Sex'].value_counts().reset_index()
visit_Sex.columns = ['UniqueValue','Count']
visit_Sex
# Out:
#   UniqueValue   Count
# 0         ชาย  693912
# 1        หญิง  646676

# %%
visit_Age = visit['Age'].value_counts().reset_index()
visit_Age.columns = ['UniqueValue','Count']
visit_Age
# Out:
#     UniqueValue  Count
# 0            68  45393
# 1            67  45249
# 2            66  44956
# 3            69  44758
# 4            71  43898
# ..          ...    ...
# 91          102     51
# 92           10     34
# 93          103     30
# 94            9     19
# 95          104     17
#
# [96 rows x 2 columns]

# %%
visit_ENTY = visit['ENTY'].value_counts().reset_index()
visit_ENTY.columns = ['UniqueValue','Count']
visit_ENTY
# Out:
#    UniqueValue    Count
# 0  Out Patient  1242495
# 1    InPatient    54283
# 2            E    43808

# %%
visit_NATNL = visit['NATNL'].value_counts().reset_index()
visit_NATNL.columns = ['UniqueValue','Count']
visit_NATNL
# Out:
#                      UniqueValue    Count
# 0                            ไทย  1329345
# 1                            ลาว     3098
# 2                       อเมริกัน     1185
# 3   บริติช  (อังกฤษ, สก็อตแลนด์)     1112
# 4                          อื่นๆ     1079
# 5                        ไม่ระบุ      544
# 6                     ออสเตรเลีย      472
# 7                        เยอรมัน      352
# 8                       เวียดนาม      226
# 9                          โอมาน      177
# 10                      เดนมาร์ก      124
# 11                           จีน      119
# 12                          สวิส      109
# 13                        อิตาลี      109
# 14                         ดัตช์      104
# 15                        แคนาดา       89
# 16                        สวีเดน       78
# 17                       ไทยลื้อ       72
# 18                      ฝรั่งเศส       56
# 19                      เขมรอพยพ       55
# 20                      นอร์เวย์       55
# 21                          สเปน       53
# 22            เซนต์คิตส์และเนวิส       41
# 23                     ไอซ์แลนด์       38
# 24                      เบลเยียม       35
# 25                      ออสเตรีย       33
# 26                       ญี่ปุ่น       29
# 27                        ซีเรีย       26
# 28                    ไร้สัญชาติ       25
# 29                  จีน(ไต้หวัน)       20
# 30                        ไซปรัส       11
# 31                          พม่า        2

# %%
# Specify the columns for unique value counting
columns_to_count = ['PatientUID', 'PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL']

# Count unique values in the specified columns
visit_count = visit[columns_to_count].value_counts().reset_index()
visit_count.columns = ['PatientUID', 'PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL', 'Count']
visit_count
# Out:
#          PatientUID  PatientvisitUID   Sex  Age         ENTY NATNL  Count
# 0              2299           144386  หญิง   70  Out Patient   ไทย      1
# 1           1120916          6593553   ชาย   60  Out Patient   ไทย      1
# 2           1120916          7752314   ชาย   61  Out Patient   ไทย      1
# 3           1120916          7747689   ชาย   61  Out Patient   ไทย      1
# 4           1120916          7737649   ชาย   61  Out Patient   ไทย      1
# ...             ...              ...   ...  ...          ...   ...    ...
# 1338866      448304          2221926   ชาย   33  Out Patient   ไทย      1
# 1338867      448304          2150381   ชาย   33  Out Patient   ไทย      1
# 1338868      448304          2138351   ชาย   33  Out Patient   ไทย      1
# 1338869      448304          2123685   ชาย   33  Out Patient   ไทย      1
# 1338870     3437526         10541118   ชาย   68  Out Patient   ไทย      1
#
# [1338871 rows x 7 columns]

# %%
columns_to_count = ['PatientUID', 'Sex', 'Age', 'ENTY', 'NATNL']

# Count unique values in the specified columns
visit_grouped = visit.groupby('PatientUID')[columns_to_count].nunique()

# Rename the columns
new_columns = ['Count_' + column for column in columns_to_count]
visit_grouped.columns = new_columns

# Merge with the existing visit_count DataFrame
visit_count = visit_count.merge(visit_grouped, on='PatientUID', how='left')

# Select the required columns
required_columns = ['PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL', 'Count_Sex', 'Count_Age', 'Count_ENTY', 'Count_NATNL']
visit_count = visit_count.reindex(required_columns, axis=1)

# %%
visit_count
# Out:
#          PatientvisitUID   Sex  Age         ENTY NATNL  Count_Sex  Count_Age  \
# 0                 144386  หญิง   70  Out Patient   ไทย          1         11
# 1                6593553   ชาย   60  Out Patient   ไทย          1          7
# 2                7752314   ชาย   61  Out Patient   ไทย          1          7
# 3                7747689   ชาย   61  Out Patient   ไทย          1          7
# 4                7737649   ชาย   61  Out Patient   ไทย          1          7
# ...                  ...   ...  ...          ...   ...        ...        ...
# 1338866          2221926   ชาย   33  Out Patient   ไทย          1          9
# 1338867          2150381   ชาย   33  Out Patient   ไทย          1          9
# 1338868          2138351   ชาย   33  Out Patient   ไทย          1          9
# 1338869          2123685   ชาย   33  Out Patient   ไทย          1          9
# 1338870         10541118   ชาย   68  Out Patient   ไทย          1          2
#
#          Count_ENTY  Count_NATNL
# 0                 2            1
# 1                 2            1
# 2                 2            1
# 3                 2            1
# 4                 2            1
# ...             ...          ...
# 1338866           3            1
# 1338867           3            1
# 1338868           3            1
# 1338869           3            1
# 1338870           2            1
#
# [1338871 rows x 9 columns]

# %%
visit_df = pd.DataFrame(visit_grouped)
visit_df
# Out:
#             Count_PatientUID  Count_Sex  Count_Age  Count_ENTY  Count_NATNL
# PatientUID
# 2299                       1          1         11           2            1
# 2304                       1          1         12           3            1
# 2312                       1          1         12           2            1
# 2354                       1          1          9           2            1
# 2362                       1          1         12           3            1
# ...                      ...        ...        ...         ...          ...
# 3421578                    1          1          2           1            1
# 3426284                    1          1          2           1            1
# 3431501                    1          1          2           1            1
# 3432056                    1          1          2           2            1
# 3437526                    1          1          2           2            1
#
# [22575 rows x 5 columns]

# %%
import pandas as pd

# กำหนดคอลัมน์ที่ต้องการนับค่าที่ไม่ซ้ำกัน
columns_to_count = ['PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL']

# จัดกลุ่มและนับค่าที่ไม่ซ้ำกันตามดัชนี "PatientUID"
visit_grouped = visit.groupby('PatientUID')[columns_to_count].nunique()

# เปลี่ยนชื่อคอลัมน์ใหม่
visit_grouped.columns = ['Count_' + column for column in columns_to_count]

# %%
visit_grouped
# Out:
#             Count_PatientvisitUID  Count_Sex  Count_Age  Count_ENTY  \
# PatientUID
# 2299                           83          1         11           2
# 2304                           67          1         12           3
# 2312                           83          1         12           2
# 2354                           64          1          9           2
# 2362                           88          1         12           3
# ...                           ...        ...        ...         ...
# 3421578                         6          1          2           1
# 3426284                         4          1          2           1
# 3431501                         4          1          2           1
# 3432056                        14          1          2           2
# 3437526                         3          1          2           2
#
#             Count_NATNL
# PatientUID
# 2299                  1
# 2304                  1
# 2312                  1
# 2354                  1
# 2362                  1
# ...                 ...
# 3421578               1
# 3426284               1
# 3431501               1
# 3432056               1
# 3437526               1
#
# [22575 rows x 5 columns]

# %%
# ตรวจสอบว่ามีค่าดัชนีซ้ำกันทั้งหมดหรือไม่
is_any_duplicated = visit_grouped.index.duplicated().any()

# %%
is_any_duplicated
# Out:
# False

# %%
visit_df = pd.DataFrame(visit_grouped)
visit_df
# Out:
#             Count_PatientvisitUID  Count_Sex  Count_Age  Count_ENTY  \
# PatientUID
# 2299                           83          1         11           2
# 2304                           67          1         12           3
# 2312                           83          1         12           2
# 2354                           64          1          9           2
# 2362                           88          1         12           3
# ...                           ...        ...        ...         ...
# 3421578                         6          1          2           1
# 3426284                         4          1          2           1
# 3431501                         4          1          2           1
# 3432056                        14          1          2           2
# 3437526                         3          1          2           2
#
#             Count_NATNL
# PatientUID
# 2299                  1
# 2304                  1
# 2312                  1
# 2354                  1
# 2362                  1
# ...                 ...
# 3421578               1
# 3426284               1
# 3431501               1
# 3432056               1
# 3437526               1
#
# [22575 rows x 5 columns]

# %% [markdown]
# #Merge File 📝

# %%
with pd.ExcelWriter('CountUniqueValues.xlsx') as writer:
    vitalsign_df.to_excel(writer, sheet_name='Vitalsign')
    diag_df.to_excel(writer, sheet_name='Diagnosis')
    lab_df.to_excel(writer, sheet_name='Lab')
    pre_df.to_excel(writer, sheet_name='Prescription')
    visit_df.to_excel(writer, sheet_name='Visit', index=False)
