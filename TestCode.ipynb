# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/PROJECT/blob/main/TestCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_excel('/content/drive/MyDrive/ckdresearch2023/Assign/SummaryFile/WideTable/WideTable.xlsx')
df = df.iloc[:, 1:]
df.head()
# Out:
#    PatientUID  PatientVisitUID     Slopes  G1M2:ARB  G3M1:Statin  G5M2:NSAIDs  \
# 0        2299          5812902  -7.158596       100          100           34
# 1        2299          6947220   5.550691        35            0            1
# 2        2299          8186767  -6.063710       100            0           15
# 3        2299          9385133 -12.812245        90            0            0
# 4        2304          4916314  28.287500         0            0            0
#
#    G1M5:Diuretic  G1M7:Beta blocker  G1M3:Dihydropyridine CCB  G1M6:MRA  ...  \
# 0              0                  0                         0         0  ...
# 1             35                  0                         0         0  ...
# 2              0                  0                         0         0  ...
# 3              0                  0                         0         0  ...
# 4              0                  0                         0         0  ...
#
# ...

# %%
lab = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Lab.csv')

import pandas as pd

# Step 1: Compute mode of 'Location' for each 'PatientUID' in 'lab' table
mode_location = lab.groupby('PatientUID')['Location'].apply(lambda x: x.mode()[0]).reset_index()

# Step 2: Create a dictionary mapping 'PatientUID' to mode 'Location'
mode_dict = dict(zip(mode_location['PatientUID'], mode_location['Location']))

# Step 3: Fill null values in the 'Location' column of 'df' with the mode values
df['Location'] = df.apply(lambda row: mode_dict[row['PatientUID']] if pd.isnull(row['Location']) else row['Location'], axis=1)

# %%
data = pd.DataFrame(df)
remove = ['L12:Hemoglobin','L13:Hematocrit','L16:TIBC','L17:Tranferin SAT',
          'L18:Ferritin','L25:Parathyroid hormone','L26:Vitamin D','L27:UrineAlbumin/Cr ratio',
          'L28:UrineProtein/Cr ratio','L29:UrineVolume (24hrs)','L30:UrineUrea (24hrs)',
          'L31:UrineSodium (24hrs)','L32:UrineProtein (24hrs)']
data = data.drop(remove, axis=1)

# %%
data['Age'] = data['Age'].fillna('69')
data['Sex'] = data['Sex'].fillna('หญิง')
data['NATNL'] = data['NATNL'].fillna('ไทย')
data['InPatient'] = data['InPatient'].fillna(0)
data['OutPatient'] = data['OutPatient'].fillna(1)
data['Emergency'] = data['Emergency'].fillna(0)
data['PricipalProblemCode'] = data['PricipalProblemCode'].fillna('None')
data['PricipalProblemName'] = data['PricipalProblemName'].fillna('None')

# %%
import pandas as pd
column_to_exclude = 'Slopes'
null_columns = data.columns[data.isnull().any()]
numeric_non_null_columns = data.select_dtypes(include=[float, int]).columns[~data.select_dtypes(include=[float, int]).isnull().any() & (data.select_dtypes(include=[float, int]).columns != column_to_exclude)]
data[null_columns] = data[null_columns].apply(pd.to_numeric, errors='coerce')
correlation_matrix = data.corr()
correlation = correlation_matrix.loc[null_columns, numeric_non_null_columns]
# Out:
# <ipython-input-6-cb709e0075f0>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %% [markdown]
# **check type**

# %%
print(data[numeric_non_null_columns].dtypes)
# Out:
# PatientUID                        int64
# PatientVisitUID                   int64
# G1M2:ARB                          int64
# G3M1:Statin                       int64
# G5M2:NSAIDs                       int64
# G1M5:Diuretic                     int64
# G1M7:Beta blocker                 int64
# G1M3:Dihydropyridine CCB          int64
# G1M6:MRA                          int64
# G1M1:ACEI                         int64
# G2M2:Metformin                    int64
# G2M3:DPP4 inhibitor               int64
# G2M1:SU                           int64
# G3M3:Fibrate                      int64
# G2M5:SGLT2i                       int64
# G4M1:Allopurinol                  int64
# G1M9:Vasodilator                  int64
# G1M8:Alpha blocker                int64
# G2M6:Insulin                      int64
# G2M4:TZD                          int64
# G4M2:Febuxostat                   int64
# G3M2:Ezetimibe                    int64
# G1M4:Non-dihydropyridine CCB      int64
# ...

# %%
print(data[null_columns].dtypes)
# Out:
# Systolic BP            float64
# Diastolic BP           float64
# BMI                    float64
# BSA                    float64
# L2:BUN                 float64
# L3:Creatinine          float64
# L4:Sodium              float64
# L5:Potassium           float64
# L6:Chloride            float64
# L7:Bicarbonate         float64
# L8:Uric                float64
# L9:Calcium             float64
# L10:Phosphorus         float64
# L11:Albumin            float64
# L15:Platelet           float64
# L19:Blood sugar        float64
# L20:HbA1c              float64
# L21:Cholesterol        float64
# L22:Triglyceride       float64
# L23:LDL Cholesterol    float64
# L24:HDL Cholesterol    float64
# L14:WBC                float64
# dtype: object

# %%
# !pip install missingpy
# !pip install MissForest
import pandas as pd
import numpy as np
from missforest.missforest import MissForest

# %%
# Store the original column names
original_columns = {}
for col in data:
    original_columns[col.replace(" ", "").replace(":", "").replace("-", "").replace("/", "").replace("&", "").replace("#", "")] = col
    # Rename only null_missforest columns
for col in data:
    data = data.rename(columns={col: col.replace(" ", "").replace(":", "").replace("-", "").replace("/", "").replace("&", "").replace("#", "")})

# %%
print(data.columns)
# Out:
# Index(['PatientUID', 'PatientVisitUID', 'Slopes', 'G1M2ARB', 'G3M1Statin',
#        'G5M2NSAIDs', 'G1M5Diuretic', 'G1M7Betablocker',
#        'G1M3DihydropyridineCCB', 'G1M6MRA', 'G1M1ACEI', 'G2M2Metformin',
#        'G2M3DPP4inhibitor', 'G2M1SU', 'G3M3Fibrate', 'G2M5SGLT2i',
#        'G4M1Allopurinol', 'G1M9Vasodilator', 'G1M8Alphablocker', 'G2M6Insulin',
#        'G2M4TZD', 'G4M2Febuxostat', 'G3M2Ezetimibe',
#        'G1M4NondihydropyridineCCB', 'G5M1Ketoanalogaminoacid', 'G2M7GLP1RA',
#        'G4M3Uricosuricagent', 'D1Hypertension', 'D2Diabetesmillitus',
#        'D3Dyslipidemia', 'D4SLE', 'D5Systemicsclerosis',
#        'D6Rheumatoidarthritis', 'D7HIVinfection', 'D8HBVinfection',
#        'D9HCVinfection', 'D10Ischemicheartdisease', 'D11Heartfailure',
#        'SystolicBP', 'DiastolicBP', 'BMI', 'BSA', 'L2BUN', 'L3Creatinine',
#        'L4Sodium', 'L5Potassium', 'L6Chloride', 'L7Bicarbonate', 'L8Uric',
#        'L9Calcium', 'L10Phosphorus', 'L11Albumin', 'L15Platelet',
# ...

# %%
# List of columns to exclude
columns_to_exclude = ['Slopes', 'Sex', 'Age', 'NATNL', 'Location', 'PricipalProblemCode', 'PricipalProblemName']

# Select only numeric columns
numeric_columns = data.select_dtypes(include=[float, int]).columns

# Filter out the excluded columns
filtered_columns = [col for col in numeric_columns if col not in columns_to_exclude]

# Filter the DataFrame
data_filtered = data[filtered_columns]

# %%
data.shape
# Out:
# (52619, 70)

# %%
# Check for null values in the DataFrame
null_values = data_filtered.isnull().values.any()

if null_values:
    print("DataFrame contains null values.")
else:
    print("DataFrame does not contain null values.")
# Out:
# DataFrame does not contain null values.

# %%
print(data_filtered.shape)
print(data_filtered.info())
# Out:
# (52619, 63)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52619 entries, 0 to 52618
# Data columns (total 63 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientUID                 52619 non-null  int64
#  1   PatientVisitUID            52619 non-null  int64
#  2   G1M2ARB                    52619 non-null  int64
#  3   G3M1Statin                 52619 non-null  int64
#  4   G5M2NSAIDs                 52619 non-null  int64
#  5   G1M5Diuretic               52619 non-null  int64
#  6   G1M7Betablocker            52619 non-null  int64
#  7   G1M3DihydropyridineCCB     52619 non-null  int64
#  8   G1M6MRA                    52619 non-null  int64
#  9   G1M1ACEI                   52619 non-null  int64
#  10  G2M2Metformin              52619 non-null  int64
#  11  G2M3DPP4inhibitor          52619 non-null  int64
#  12  G2M1SU                     52619 non-null  int64
# ...

# %%
# Check if the data is 2-dimensional and not empty
if data_filtered.empty or data_filtered.shape[1] < 2:
    raise ValueError("Input data must be 2 dimensional and non-empty.")

# Initialize the MissForest imputer
imputer = MissForest()

# Fit and transform the specified columns using MissForest
data_imputed = imputer.fit_transform(data_filtered)

# Create a new DataFrame with imputed values
imputed_data = pd.DataFrame(data_imputed, columns=filtered_columns)

# Update the original DataFrame with the imputed values
data.update(imputed_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/missforest/missforest.py:240: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[c].fillna(impute_vals, inplace=True)
# /usr/local/lib/python3.10/dist-packages/missforest/missforest.py:240: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[c].fillna(impute_vals, inplace=True)
# /usr/local/lib/python3.10/dist-packages/missforest/missforest.py:240: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
