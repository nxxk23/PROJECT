# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/PROJECT/blob/main/Prescription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
prescription = pd.read_csv('/content/drive/MyDrive/Thesis Project Kidney/Prescription.csv')
prescription.head()
# Out:
#    PatientUID  PatientVisitUID            DispensedDttm  \
# 0        2299          2024049  2558-02-19 14:48:15.693
# 1        2299          2024049  2558-02-19 14:48:15.693
# 2        2299          2024049  2558-02-19 14:48:15.693
# 3        2299          2024049  2558-02-19 14:48:15.693
# 4        2299          2024049  2558-02-19 14:47:55.953
#
#                        DrugName                    GenericName  Quantity  \
# 0           Folic Acid 5 mg TAB               Folivit tab 5 mg      90.0
# 1         Vitamin B Complex TAB          Vitamin B Complex TAB     180.0
# 2   losartan(Loranta) 50 mg TAB  Loranta film-coated tab 50 mg      90.0
# 3  lorazepam(Anxira) 0.5 mg TAB              Anxira tab 0.5 mg      30.0
# 4              ChalkTAB-1.5 TAB               Chalktab 1500 mg      90.0
#
#                               DrugFrequency  Dosage DosageForm  DrugDuration
# 0        od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB          90.0
# 1  bid pc |วันละ 2 ครั้ง หลังอาหารเช้า เย็น     1.0      1 TAB          90.0
# 2        od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB          90.0
# 3                 hs |วันละ 1 ครั้ง ก่อนนอน     1.0      1 TAB          30.0
# 4        od pc |วันละ 1 ครั้ง หลังอาหารเช้า     1.0      1 TAB          90.0

# %%
prescription = prescription[['DrugName', 'GenericName']]
prescription['DrugName'] = prescription['DrugName'].str.lower()
prescription['GenericName'] = prescription['GenericName'].str.lower()
prescription['DrugName'].fillna(' ', inplace=True)
prescription['GenericName'].fillna(' ', inplace=True)
prescription
# Out:
#                                                   DrugName  \
# 0                                      folic acid 5 mg tab
# 1                                    vitamin b complex tab
# 2                              losartan(loranta) 50 mg tab
# 3                             lorazepam(anxira) 0.5 mg tab
# 4                                         chalktab-1.5 tab
# ...                                                    ...
# 9530447                   infusion plabottle set (iv.set)
# 9530448                      normal saline 0.9% iv 1000 ml
# 9530449                       normal saline 0.9% iv 100 ml
# 9530450          minimun volume extension with t connector
# 9530451  intravenous disposable catheter ch.20 ความยาวป...
#
#                            GenericName
# 0                     folivit tab 5 mg
# 1                vitamin b complex tab
# 2        loranta film-coated tab 50 mg
# 3                    anxira tab 0.5 mg
# 4                     chalktab 1500 mg
# ...                                ...
# 9530447
# 9530448  normal saline 0.9% iv 1000 ml
# 9530449   normal saline 0.9% iv 100 ml
# 9530450
# 9530451
#
# [9530452 rows x 2 columns]

# %%
drug = prescription['DrugName'].tolist()
gen = prescription['GenericName'].tolist()

# %%
drug_split = [name.split() for name in drug]
gen_split = [name.split() for name in gen]

# %%
drug_split
# Out:
# [['folic', 'acid', '5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['chalktab-1.5', 'tab'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['gabapentin(gabutin)', '300', 'mg', 'cap'],
#  ['gabapentin(rontin)', '600', 'mg', 'cap'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['chalktab-1.5', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['voltaren', 'sr', '100', 'mg', 'tab', '(ฝาก)'],
#  ['caltab-1500', 'tab'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['spasmo-lyt', '20', 'mg', 'tab', '(ฝาก)'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['caltab-1500', 'tab'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['เฝือกพยุงระดับเอว', 'l', '-', 's', 'support', 'no.', 'l'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['gabapentin(gabutin)300', 'mg', 'cap'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['caltab-1500', 'tab'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['caltab-1500', 'tab'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['gabapentin(gabutin)300', 'mg', 'cap'],
#  ['caltab-1500', 'tab'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['caltab-1500', 'tab'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['vitamin', 'd2', '20,000', 'u'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['caltab-1500', 'tab'],
#  ['protaxos', '2', 'gm', 'granule'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['caltab-1500', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['caltab-1500', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['difengesic', 'gel', '35', 'gm'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['ibuprofen(duran)', '400mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['difengesic', 'gel', '35', 'gm'],
#  ['vitamin', 'b6(besix)', '100', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['vitamin', 'b6(besix)', '100', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['orkelax', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['caltab-1000', 'tab'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['orkelax', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['arcoxia', '30', 'mg', 'tab'],
#  ['furosemide', '40', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['lorazepam(anxira)', '1', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['furosemide', '40', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['furosemide', '40', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['swiff', 'solution', '90', 'ml'],
#  ['three', 'ways', 'disposable', 'stopcock'],
#  ['intravenous', 'disposable', 'catheter', 'ch.20', 'ความยาวประมาณ', '1.1/4"'],
#  ['infusion', 'plabottle', 'set', '(iv.set)'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['furosemide', '40', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['แผ่นสำหรับตรวจการติดเชื้อเฮลิโคแบคเตอร์', 'ไพโลไร'],
#  ['xylocaine', '2%', 'inj', '1', 'ml'],
#  ['glyco-p', 'inj', '0.2', 'mg'],
#  ['ephedrine', '30', 'mg/1', 'ml', 'inj'],
#  ['propofol-lipuro', '10', 'mg/ml', '50ml', 'inj'],
#  ['propofol(fresofol)', '200', 'mg', 'inj'],
#  ['fentanyl', '0.05', 'mg/ml', 'inj', '2', 'ml'],
#  ['amoxycillin', '500', 'mg', 'cap'],
#  ['clarithromycin(fascar)', '500', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['transparent', 'dressing', 'ขนาด', '6cm.x', '7cm.'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['arcoxia', '30', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['celebrex', '400', 'mg', 'cap'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['folic', 'acid', '5', 'mg', 'tab'],
#  ['celebrex', '400', 'mg', 'cap'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['duocetz', '325/37.5', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['celebrex', '400', 'mg', 'cap'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['celebrex', '400', 'mg', 'cap'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['cyproheptadine', '4', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['optive', 'fusion', 'eye', 'drop', '10', 'ml'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['optive', 'fusion', 'eye', 'drop', '10', 'ml'],
#  ['natear', '0.3%', 'eye', 'drop', '10', 'ml'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['vitamin', 'b', '1-6-12', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['sertraline(sisalon)', '50', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['poly-oph', 'eye', 'drop', '10', 'ml'],
#  ['natear', '0.3%', 'eye', 'drop', '10', 'ml'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['valdoxan', '25', 'mg', 'tab'],
#  ['reminyl', 'pr', '8', 'mg', 'tab'],
#  ['reminyl', 'pr', '8', 'mg', 'tab'],
#  ['tebonin', 'forte', '120', 'mg', 'tab'],
#  ['trazodel', '50', 'mg', 'tab'],
#  ['valdoxan', '25', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['reminyl', 'pr', '16', 'mg', 'tab'],
#  ['lorazepam(anxira)', '0.5', 'mg', 'tab'],
#  ['valdoxan', '25', 'mg', 'tab'],
#  ['trazodel', '50', 'mg', 'tab'],
#  ['tebonin', 'forte', '120', 'mg', 'tab'],
#  ['natear', '0.3%', 'eye', 'drop', '10', 'ml'],
#  ['losartan(loranta)', '50', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['atorvastatin(lipostat)', '40mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['prenolol', '50', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(lipostat)', '40mg', 'tab'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['k.k.', 'balm', '15', 'gm'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(lipostat)', '40mg', 'tab'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['prenolol', '50', 'mg', 'tab'],
#  ['milk', 'of', 'magnesia(gpo)', 'suspension', '240', 'ml'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['atorvastatin(lipostat)', '40mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['milk', 'of', 'magnesia(gpo)', 'suspension', '240', 'ml'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['omeprazole(gpo)', '20', 'mg', 'cap'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['air-x', 'tab'],
#  ['air-x', 'tab'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['omeprazole(gpo)', '20', 'mg', 'cap'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['ors', 'powder', '4.253', 'gm'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['metoclopramide(gpo)', '10mg/2ml', 'inj'],
#  ['osid', 'inj', '40', 'mg'],
#  ['in-stopper(heparin',
#   'lock)',
#   'closeing',
#   'stopper',
#   'for',
#   'intrtmitent',
#   'injection'],
#  ['intravenous', 'disposable', 'catheter', 'ch.22', 'ความยาวประมาณ', '1"'],
#  ['onsia', '8', 'mg', 'inj'],
#  ['unison', 'enema', 'solution', '100', 'ml'],
#  ['normal', 'saline', '0.9%', 'iv', '1000', 'ml'],
#  ['ชุดให้สารละลายทางหลอดเลือดดำสำหรับเครื่อง', 'infusion', 'pump'],
#  ['three', 'ways', 'disposable', 'stopcock'],
#  ['extension', 'tube', 'ความจุ', '2.0', 'ml.length', '18"'],
#  ['intravenous', 'disposable', 'catheter', 'ch.20', 'ความยาวประมาณ', '1.1/4"'],
#  ['stomach', 'tube', 'ng.disposable', 'length', '16', 'fr.125', 'cm.'],
#  ['ors', 'powder', '16.50', 'gm.'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['plasil', '10', 'mg', 'tab'],
#  ['unison', 'enema', 'solution', '100', 'ml'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['air-x', 'tab'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['omeprazole(gpo)', '20', 'mg', 'cap'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['k.k.', 'balm', '15', 'gm'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['normal', 'saline', '0.9%', 'iv', '1000', 'ml'],
#  ['onsia', '8', 'mg', 'inj'],
#  ['three', 'ways', 'disposable', 'stopcock'],
#  ['infusion', 'plabottle', 'set', '(iv.set)'],
#  ['extension', 'tube', 'ความจุ', '2.0', 'ml.length', '18"'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['ors', 'powder', '16.50', 'gm.'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['difengesic', 'gel', '35', 'gm'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '20mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['chlorpheniramine(cpn)', '10', 'mg/ml', 'inj'],
#  ['dexamethasone(lodexa)', '4mg/ml', 'inj', '2', 'ml'],
#  ['intravenous', 'disposable', 'catheter', 'ch.24', 'ความยาวประมาณ', '3/4"'],
#  ['hydroxyzine', '10', 'mg', 'tab'],
#  ['triamcinolone', '0.1%', 'cream', '5', 'gm'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['k.k.', 'balm', '15', 'gm'],
#  ['chlorpheniramine(cpn)', '4', 'mg', 'tab'],
#  ['orkelax', 'tab'],
#  ['ibuprofen(duran)', '400mg', 'tab'],
#  ['a', 'm', 'k', '1', 'gm', 'tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['orkelax', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['k.k.', 'balm', '15', 'gm'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['atorvastatin(xarator)', '40mg', 'tab'],
#  ['biocalm', '50', 'mg', 'tab'],
#  ['diclofenac', '25', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['prenolol', '25', 'mg', 'tab'],
#  ['prenolol', '25', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '10', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['prenolol', '25', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['prenolol', '25', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '20(ยี่สิบ)', 'mg', 'tab'],
#  ['norvasc', '10', 'mg', 'tab', '(ฝาก)'],
#  ['prenolol', '25', 'mg', 'tab'],
#  ['simvastatin(bestatin)', '20(ยี่สิบ)', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['kanolone', '10mg/ml', 'inj', '1ml'],
#  ['xylocaine', '1%', '1ml'],
#  ['zithromax', '250', 'mg', 'cap(ฝาก)'],
#  ['prednisolone', '5', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['fluimucil', '200', 'mg', 'granule'],
#  ['zithromax', '250', 'mg', 'cap(ฝาก)'],
#  ['fluimucil', '200', 'mg', 'granule'],
#  ['hialid', 'eye', 'drop', '5', 'ml'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['xylocaine', '1%', '1ml'],
#  ['kanolone', '10mg/ml', 'inj', '1ml'],
#  ['hialid', 'eye', 'drop', '5', 'ml'],
#  ['xylocaine', '1%', '1ml'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['kanolone', '10mg/ml', 'inj', '1ml'],
#  ['augmentin', '1', 'gm', 'tab(ฝาก)'],
#  ['codepect', 'cap'],
#  ['telfast', '60', 'mg', 'cap'],
#  ['n.s.s.irrigate', '1000ml(plastic)'],
#  ['syringe', 'disposable', '20', 'cc'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['เฝือกพยุงระดับเอว',
#   'l',
#   '-',
#   's',
#   'support',
#   'no.',
#   'm',
#   'ขนาดรอบเอว',
#   '30"-34"'],
#  ['เฝือกพยุงระดับเอว',
#   'l',
#   '-',
#   's',
#   'support',
#   'no.',
#   'l',
#   'ขนาดรอบเอว',
#   '35"-39"'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['เฝือกพยุงระดับเอว',
#   'l',
#   '-',
#   's',
#   'support',
#   'no.',
#   'l',
#   'ขนาดรอบเอว',
#   '35"-39"'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['ossium', '200', 'mg', 'tab'],
#  ['caltab-1000', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['dexamethasone(lodexa)', '4mg/ml', 'inj', '2', 'ml'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['caltab-1000', 'tab'],
#  ['ossium', '200', 'mg', 'tab'],
#  ['harnal', 'ocas', '0.4mg', 'tab'],
#  ['rowatinex', '100', 'mg'],
#  ['pocitrin', 'tab'],
#  ['co-trimoxazole', 'tab', '(80+400)'],
#  ['ossium', '200', 'mg', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['dexamethasone(lodexa)', '4mg/ml', 'inj', '2', 'ml'],
#  ['normal', 'saline', '0.9%', 'iv', '1000', 'ml'],
#  ['cef-3', '2', 'gm', 'inj'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['ossium', '200', 'mg', 'tab'],
#  ['ossium', '200', 'mg', 'tab'],
#  ['artrodar', '50', 'mg', 'cap'],
#  ['daflon', '500', 'mg', 'tab'],
#  ['arcoxia', '90', 'mg', 'tab'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['trancon', '5', 'mg', 'cap'],
#  ['a', 'm', 'k', '1', 'gm', 'tab'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['voltaren', 'sr', '100', 'mg', 'tab', '(ฝาก)'],
#  ['methimazole', '5', 'mg', 'tab'],
#  ['a', 'm', 'k', '1', 'gm', 'tab'],
#  ['methimazole', '5', 'mg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '50', 'mcg', 'tab'],
#  ['thyrosit', '50', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['xylocaine', '1%', '1ml'],
#  ['kanolone', '10mg/ml', 'inj', '1ml'],
#  ['vitamin', 'b', '1', '100', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['vitamin', 'b', '1', '100', 'mg', 'tab'],
#  ['kanolone', '10mg/ml', 'inj', '1ml'],
#  ['xylocaine', '1%', '1ml'],
#  ['artrodar', '50', 'mg', 'cap(ห้ามเบิก)'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['vitamin', 'b', '1', '100', 'mg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['hyruan', 'one', '60mg/3ml', 'inj'],
#  ['vitamin', 'b', '1', '100', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['lorazepam(anxira)', '1', 'mg', 'tab'],
#  ['vitamin', 'b', '1', '100', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '50', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['vitamin', 'b', '1', '100', 'mg', 'tab'],
#  ['lorazepam(anxira)', '1', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['xylocaine', '1%', '1ml'],
#  ['kanolone', '10mg/ml', 'inj', '1ml'],
#  ['lorazepam(anxira)', '1', 'mg', 'tab'],
#  ['viartril-s', '500', 'mg', 'cap'],
#  ['thyrosit', '100', 'mcg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['lorazepam(anxira)', '1', 'mg', 'tab'],
#  ['lyrica', 'tab', '75', 'mg'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['biocalm', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['pregabalin(sandoz)', '25', 'mg', 'cap'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['biocalm', '50', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['lyrica', 'tab', '75', 'mg'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['lyrica', 'tab', '75', 'mg'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['orphenadrine+paracetamol(torrent)', '35/450', 'mg', 'tab'],
#  ['furosemide', '40', 'mg', 'tab'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['duphalac', 'stick', '15ml', 'syrup'],
#  ['senolax', '7.5', 'mg', 'tab'],
#  ['เครื่องช่วยเดินชนิด',
#   '4',
#   'ขา',
#   'วอล์คเกอร์อลูมิเนียม',
#   '/',
#   'walker',
#   'flame'],
#  ['vitamin', 'b', 'complex', 'ed.tab'],
#  ['nortryptylene(nortyline)', '10', 'mg', 'tab'],
#  ['lyrica', 'tab', '75', 'mg'],
#  ['เฝือกพยุงระดับเอว',
#   'l',
#   '-',
#   's',
#   'support',
#   'no.',
#   'l',
#   'ขนาดรอบเอว',
#   '35"-39"'],
#  ['furosemide', '40', 'mg', 'tab'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['primovist', 'inj(จ่ายยา)'],
#  ['k.k.', 'balm', '15', 'gm'],
#  ['myonal', '50', 'mg', 'tab'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['influenza', 'vaccine', 'single', 'dose(สปสช)'],
#  ['influenza', 'vaccine', 'single', 'dose(สปสช)'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['pharmadol', '50mg/1', 'ml', 'inj'],
#  ['in-stopper(heparin',
#   'lock)',
#   'closeing',
#   'stopper',
#   'for',
#   'intrtmitent',
#   'injection'],
#  ['intravenous', 'disposable', 'catheter', 'ch.22', 'ความยาวประมาณ', '1"'],
#  ['colchicine', '0.6', 'mg', 'tab'],
#  ['k.k.', 'balm', '15', 'gm'],
#  ['caltab-1000', 'tab'],
#  ['controloc', '20mgtab'],
#  ['paracetamol', '500', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['naproxen', '250', 'mg', 'tab'],
#  ['omeprazole(miracid)', '20', 'mg', 'cap'],
#  ['spironolactone(hyles)', '25', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['losartan(loranta)', '100', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['aspirin(aspent', 'm)', '81', 'mg', 'tab'],
#  ['gaszym', 'tab'],
#  ['duphalac', 'stick', '15ml', 'syrup'],
#  ['ganaton', '50', 'mg', 'tab'],
#  ['mucosta', '100', 'mg', 'tab'],
#  ['controloc', '20mgtab'],
#  ['controloc', '20mgtab'],
#  ['chlorpheniramine(cpn)', '4', 'mg', 'tab'],
#  ['gaszym', 'tab'],
#  ['ganaton', '50', 'mg', 'tab'],
#  ['metronidazole', '200', 'mg', 'tab'],
#  ['clarithromycin(fascar)', '500', 'mg', 'tab'],
#  ['amoxycillin', '500', 'mg', 'cap'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['januvia', '100', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['januvia', '100', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['januvia', '100', 'mg', 'tab'],
#  ['januvia', '100', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['carminative', 'mixture', '180ml'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['multivitamin', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['clonazepam(prenapil)', '2', 'mg', 'tab'],
#  ['antacil', 'hh', '240', 'ml'],
#  ['carminative', 'mixture', '180ml'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['molax-m', '10', 'mg', 'tab'],
#  ['carminative', 'mixture', '180ml'],
#  ['antacil', 'hh', '240', 'ml'],
#  ['clonazepam(prenapil)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['multivitamin', 'tab'],
#  ['multivitamin', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['clonazepam(prenapil)', '2', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['clonazepam(prenapil)', '2', 'mg', 'tab'],
#  ['clonazepam(prenapil)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '10', 'mg', 'tab'],
#  ['clonazepam(prenapil)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['orfarin', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['orfarin', '3', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['orfarin', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['amlodipine(amlopine)', '5', 'mg', 'tab'],
#  ['orfarin', '5', 'mg', 'tab'],
#  ['befarin', '5', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['orfarin', '3', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['glipizide(dipazide)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['orfarin', '3', 'mg', 'tab'],
#  ['hydrochlorothiazide', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '5', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['urea', '10%(diabederm)', '35', 'gm'],
#  ['elomet', 'lotion', '30', 'ml'],
#  ['bilaxten', '20', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['edarbyclor', '40/12.5', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['edarbyclor', '40/12.5', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['urea', '10%(diabederm)', '35', 'gm'],
#  ['elomet', 'lotion', '30', 'ml'],
#  ['bilaxten', '20', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['zemiglo', '50', 'mg', 'tab'],
#  ['zemiglo', '50', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['bilaxten', '20', 'mg', 'tab'],
#  ['elomet', 'lotion', '30', 'ml'],
#  ['urea', '10%(diabederm)', '35', 'gm'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['fenofibrate(lipothin)', '200', 'mg', 'cap'],
#  ['zemiglo', '50', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['ฝาปิดจุก', 'three', 'way', 'sterile'],
#  ['zemiglo', '50', 'mg', 'tab'],
#  ['fenofibrate(lipothin)', '200', 'mg', 'cap'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['tramadol', '50', 'mg', 'cap'],
#  ['extension', 'tube', 'ความจุ', '2.0', 'ml.length', '18"'],
#  ['three', 'ways', 'disposable', 'stopcock'],
#  ['infusion', 'plabottle', 'set', '(iv.set)'],
#  ['intravenous', 'disposable', 'catheter', 'ch.20', 'ความยาวประมาณ', '1.1/4"'],
#  ['furosemide(gpo)', '20mg/2ml', 'inj'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['ฝาปิดจุก', 'three', 'way', 'sterile'],
#  ['n.s.s.', 'inj', '10', 'ml'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['n.s.s.', 'inj', '10', 'ml'],
#  ['ferrous', 'fumarate', '200mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['cold', 'cream', '(heb)', '100', 'gm'],
#  ['sodamint', '300', 'mg', 'tab'],
#  ['atorvastatin', 'sandoz', '40', 'mg', 'tab'],
#  ['trajenta', '5', 'mg', 'tab'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['fenofibrate(lipothin)', '200', 'mg', 'cap'],
#  ['zemiglo', '50', 'mg', 'tab'],
#  ['caraten', '6.25', 'mg', 'tab'],
#  ['mevalotin', '20', 'mg', 'tab'],
#  ['madiplot', '20', 'mg', 'tab'],
#  ['siamformet', '500', 'mg', 'tab'],
#  ['digoxin(lanoxin)', '0.25', 'mg', 'tab'],
#  ['bilaxten', '20', 'mg', 'tab'],
#  ['elomet', 'lotion', '30', 'ml'],
#  ['urea', '10%(diabederm)', '35', 'gm'],
#  ['แอนนาพริล(enalapril)', '5', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '3', 'mg', 'tab'],
#  ['warfarin', '(maforan)', '2', 'mg', 'tab'],
#  ['forxiga', '10', 'mg', 'tab'],
#  ...]

# %%
drug_split1 = [name.split()[0] for name in drug]
gen_split1 = [name.split()[0] for name in gen]

# %%
drug_split1
