# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/PROJECT/blob/main/CheckVisit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
hemo = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Hemodialysis.csv', encoding='latin1')

# %%
visit = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Visit.csv')
visit.head()
# Out:
# <ipython-input-3-d66278be1d30>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   visit = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Visit.csv')
#    PatientUID  PatientvisitUID   Sex  Age         ENTY NATNL  \
# 0       19319            25325  หญิง   83  Out Patient   ไทย
# 1       83224            25327   ชาย   64  Out Patient   ไทย
# 2      160455            25336   ชาย   86  Out Patient   ไทย
# 3      181216            25338  หญิง   82  Out Patient   ไทย
# 4      568147            25357   ชาย   68  Out Patient   ไทย
#
#                  StartDTTM                  EndDttm Location  \
# 0  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 1  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 2  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 3  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
# 4  2555-01-01 00:00:00.000  2557-11-26 23:58:59.730      NaN
#
#   PricipalProblemCode PricipalProblemName
# 0                 NaN                 NaN
# 1                 NaN                 NaN
# 2                 NaN                 NaN
# 3                 NaN                 NaN
# 4                 NaN                 NaN

# %%
# Create a list from hemo['PatientUID']
patient_uid_list = hemo['PatientUID'].unique().tolist()
# Remove patient UIDs from visit['PatientUID'] that are not in the list
visit = visit[~visit['PatientUID'].isin(patient_uid_list)]
visit.shape
# Out:
# (1195332, 11)

# %%
selected = visit[['PatientUID', 'PatientvisitUID', 'Sex', 'Age', 'ENTY', 'NATNL', 'Location', 'StartDTTM', 'EndDttm']]
selected
# Out:
#          PatientUID  PatientvisitUID   Sex  Age         ENTY NATNL  \
# 0             19319            25325  หญิง   83  Out Patient   ไทย
# 1             83224            25327   ชาย   64  Out Patient   ไทย
# 2            160455            25336   ชาย   86  Out Patient   ไทย
# 3            181216            25338  หญิง   82  Out Patient   ไทย
# 4            568147            25357   ชาย   68  Out Patient   ไทย
# ...             ...              ...   ...  ...          ...   ...
# 1340582      738719         10575302   ชาย   61  Out Patient   ไทย
# 1340583     2738720         10575306  หญิง   69  Out Patient   ไทย
# 1340584     2720813         10575337   ชาย   65  Out Patient   ไทย
# 1340586      135860         10575384  หญิง   80  Out Patient   ไทย
# 1340587     2057262         10575392   ชาย   83  Out Patient   ไทย
#
#                                              Location  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 1340582                          ห้องจ่ายยากลาง-S1PHA
# 1340583  หน่วยทะเบียนกลาง(Test พิเศษ)เวชศาสตร์ชันสูตร
# 1340584                บูรณาการนอกเวลา (คลินิก)-OD191
# 1340586                          PCU สามเหลี่ยม-DV263
# 1340587                          ห้องจ่ายยากลาง-S1PHA
#
#                        StartDTTM                  EndDttm
# 0        2555-01-01 00:00:00.000  2557-11-26 23:58:59.730
# 1        2555-01-01 00:00:00.000  2557-11-26 23:58:59.730
# 2        2555-01-01 00:00:00.000  2557-11-26 23:58:59.730
# 3        2555-01-01 00:00:00.000  2557-11-26 23:58:59.730
# 4        2555-01-01 00:00:00.000  2557-11-26 23:58:59.730
# ...                          ...                      ...
# 1340582  2566-04-10 14:09:34.010                      NaN
# 1340583  2566-04-10 14:10:35.473                      NaN
# 1340584  2566-04-10 14:22:46.967                      NaN
# 1340586  2566-04-10 14:45:26.267                      NaN
# 1340587  2566-04-10 14:51:46.657                      NaN
#
# [1195332 rows x 9 columns]

# %% [markdown]
# **Slope**

# %%
import pandas as pd
slope = pd.read_excel('/content/drive/MyDrive/ckdresearch2023/Assign/SummaryFile/Slope.xlsx')

data = pd.DataFrame(slope)
data = data[['PatientUID','PatientVisitUID','Slopes']]

df = pd.DataFrame(data)

# Sorting the DataFrame by PatientUID and PatientVisitUID
df = df.sort_values(['PatientUID', 'PatientVisitUID'])

# Adding a NextSlope column
df['Slopes'] = df.groupby('PatientUID')['Slopes'].shift(-1)

data = df.dropna()
data
# Out:
#        PatientUID  PatientVisitUID     Slopes
# 0            2299          3386255  -7.158596
# 1            2299          4546471   5.550691
# 2            2299          5812902  -6.063710
# 3            2299          6947220 -12.812245
# 4            2299          8186767  28.287500
# ...           ...              ...        ...
# 73378     3319961          9270330  -4.256753
# 73380     3319971          9270331  -0.692078
# 73382     3320048          9242721   7.217875
# 73384     3320050          9257281 -32.794557
# 73388     3321289          9274735 -36.776371
#
# [52620 rows x 3 columns]

# %% [markdown]
# ```
# เก็บแค่ visit ที่อยู่ใน slope data
# ```

# %%
patient_visit_list = data['PatientVisitUID'].unique().tolist()
visit = selected[selected['PatientvisitUID'].isin(patient_visit_list)]
visit.shape
# Out:
# (52620, 9)

# %%
visit
# Out:
#          PatientUID  PatientvisitUID   Sex  Age         ENTY NATNL  \
# 252705       136689          2705230  หญิง   79    InPatient   ไทย
# 295104       142339          3061805   ชาย   62    InPatient   ไทย
# 311714      1355105          3199774   ชาย   29    InPatient   ไทย
# 317725       514974          3249012   ชาย   81    InPatient   ไทย
# 318849       478463          3258047  หญิง   77    InPatient   ไทย
# ...             ...              ...   ...  ...          ...   ...
# 1185423      369580          9336612   ชาย   74  Out Patient   ไทย
# 1185818     1130532          9339080  หญิง   78  Out Patient   ไทย
# 1186100     1002508          9341881   ชาย   86            E   ไทย
# 1187071      170289          9348665  หญิง   70  Out Patient   ไทย
# 1187113     1063019          9348880   ชาย   65  Out Patient   ไทย
#
#                                        Location                StartDTTM  \
# 252705                         หอผู้ป่วย 6จ-6EW  2558-11-22 15:08:40.640
# 295104                         หอผู้ป่วย 6จ-6EW  2559-04-11 01:43:48.503
# 311714                         หอผู้ป่วย 4ก-4AW  2559-06-04 11:13:25.293
# 317725                         หอผู้ป่วย 6ก-6AW  2559-06-22 17:01:22.230
# 318849                  หอผู้ป่วยสว.ชั้น9C-SV9C  2559-06-26 08:04:12.323
# ...                                         ...                      ...
# 1185423          บูรณาการนอกเวลา (คลินิก)-OD191  2565-04-03 06:56:02.340
# 1185818  โรคเลือดและต่อมน้ำเหลือง (คลินิก)-D716  2565-04-04 08:22:51.867
# 1186100                            OPD AE-DV191  2565-04-04 21:24:47.210
# 1187071                 รังสีวินิจฉัย (OPD)-D14  2565-04-07 07:55:56.483
# 1187113                   อายุรกรรม 8 (OPD)-D07  2565-04-07 08:12:10.387
#
#                          EndDttm
# 252705   2559-08-17 16:33:18.983
# 295104   2559-09-01 15:52:42.497
# 311714   2559-10-14 15:08:50.957
# 317725   2559-08-26 15:03:39.223
# 318849   2559-08-10 15:04:32.293
# ...                          ...
# 1185423  2565-04-04 05:01:01.943
# 1185818  2565-04-05 05:01:02.120
# 1186100  2565-04-05 05:01:03.247
# 1187071  2565-04-08 05:01:01.820
# 1187113  2565-04-08 05:01:01.820
#
# [52620 rows x 9 columns]

# %%
visit['ENTY'].unique()
# Out:
# array(['InPatient', 'Out Patient', 'E'], dtype=object)

# %% [markdown]
# **ENTY**
# - **in == 0**
# - **out == 46526**
# - **emergency == 2097**

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df' with your data
# You can create a new column 'InPatient' based on the 'ENTY' column
df = pd.DataFrame(visit)
df['InPatient'] = df['ENTY'].apply(lambda x: 1 if x == 'InPatient' else 0)
df['OutPatient'] = df['ENTY'].apply(lambda x: 1 if x == 'Out Patient' else 0)
df['Emergency'] = df['ENTY'].apply(lambda x: 1 if x == 'E' else 0)
df
# Out:
#          PatientUID  PatientvisitUID   Sex  Age         ENTY NATNL  \
# 252705       136689          2705230  หญิง   79    InPatient   ไทย
# 295104       142339          3061805   ชาย   62    InPatient   ไทย
# 311714      1355105          3199774   ชาย   29    InPatient   ไทย
# 317725       514974          3249012   ชาย   81    InPatient   ไทย
# 318849       478463          3258047  หญิง   77    InPatient   ไทย
# ...             ...              ...   ...  ...          ...   ...
# 1185423      369580          9336612   ชาย   74  Out Patient   ไทย
# 1185818     1130532          9339080  หญิง   78  Out Patient   ไทย
# 1186100     1002508          9341881   ชาย   86            E   ไทย
# 1187071      170289          9348665  หญิง   70  Out Patient   ไทย
# 1187113     1063019          9348880   ชาย   65  Out Patient   ไทย
#
#                                        Location                StartDTTM  \
# 252705                         หอผู้ป่วย 6จ-6EW  2558-11-22 15:08:40.640
# 295104                         หอผู้ป่วย 6จ-6EW  2559-04-11 01:43:48.503
# 311714                         หอผู้ป่วย 4ก-4AW  2559-06-04 11:13:25.293
# 317725                         หอผู้ป่วย 6ก-6AW  2559-06-22 17:01:22.230
# 318849                  หอผู้ป่วยสว.ชั้น9C-SV9C  2559-06-26 08:04:12.323
# ...                                         ...                      ...
# 1185423          บูรณาการนอกเวลา (คลินิก)-OD191  2565-04-03 06:56:02.340
# 1185818  โรคเลือดและต่อมน้ำเหลือง (คลินิก)-D716  2565-04-04 08:22:51.867
# 1186100                            OPD AE-DV191  2565-04-04 21:24:47.210
# 1187071                 รังสีวินิจฉัย (OPD)-D14  2565-04-07 07:55:56.483
# 1187113                   อายุรกรรม 8 (OPD)-D07  2565-04-07 08:12:10.387
#
#                          EndDttm  InPatient  OutPatient  Emergency
# 252705   2559-08-17 16:33:18.983          1           0          0
# 295104   2559-09-01 15:52:42.497          1           0          0
# 311714   2559-10-14 15:08:50.957          1           0          0
# 317725   2559-08-26 15:03:39.223          1           0          0
# 318849   2559-08-10 15:04:32.293          1           0          0
# ...                          ...        ...         ...        ...
# 1185423  2565-04-04 05:01:01.943          0           1          0
# 1185818  2565-04-05 05:01:02.120          0           1          0
# 1186100  2565-04-05 05:01:03.247          0           0          1
# 1187071  2565-04-08 05:01:01.820          0           1          0
# 1187113  2565-04-08 05:01:01.820          0           1          0
#
# [52620 rows x 12 columns]

# %%
# Rename 'PatientUID' column in 'df' to 'PatientUID' to match 'table'
df.rename(columns={'PatientvisitUID': 'PatientVisitUID'}, inplace=True)

# Merge the two DataFrames based on 'PatientUID'
table = pd.merge(data, df, on=['PatientVisitUID','PatientUID'])
table
# Out:
#        PatientUID  PatientVisitUID     Slopes   Sex  Age         ENTY NATNL  \
# 0            2299          3386255  -7.158596  หญิง   73  Out Patient   ไทย
# 1            2299          4546471   5.550691  หญิง   74  Out Patient   ไทย
# 2            2299          5812902  -6.063710  หญิง   75  Out Patient   ไทย
# 3            2299          6947220 -12.812245  หญิง   76  Out Patient   ไทย
# 4            2299          8186767  28.287500  หญิง   78  Out Patient   ไทย
# ...           ...              ...        ...   ...  ...          ...   ...
# 52615     3319961          9270330  -4.256753   ชาย   63  Out Patient   ไทย
# 52616     3319971          9270331  -0.692078  หญิง   71  Out Patient   ไทย
# 52617     3320048          9242721   7.217875   ชาย   66            E   ไทย
# 52618     3320050          9257281 -32.794557   ชาย   67  Out Patient   ไทย
# 52619     3321289          9274735 -36.776371  หญิง   61    InPatient   ไทย
#
#                                                 Location  \
# 0                             เวชปฏิบัติทั่วไป (OPD)-D03
# 1                             เวชปฏิบัติทั่วไป (OPD)-D03
# 2                             เวชปฏิบัติทั่วไป (OPD)-D03
# 3                             เวชปฏิบัติทั่วไป (OPD)-D03
# 4                             เวชปฏิบัติทั่วไป (OPD)-D03
# ...                                                  ...
# 52615                     บูรณาการนอกเวลา (คลินิก)-OD191
# 52616                     บูรณาการนอกเวลา (คลินิก)-OD191
# 52617                                       OPD AE-DV191
# 52618  หน่วยคลินิกเฉพาะทางศูนย์บริการทางการแพทย์ชั้นเลิศ
# 52619                         หอผู้ป่วยพิเศษ กว.7/1-KV7A
#
#                      StartDTTM                  EndDttm  InPatient  \
# 0      2559-08-15 08:13:26.043  2559-08-16 05:01:01.473          0
# 1      2560-10-03 07:37:22.777  2560-10-04 05:01:01.903          0
# 2      2561-12-12 07:58:57.190  2561-12-13 05:01:01.250          0
# 3      2562-12-19 08:19:38.647  2562-12-20 05:01:01.910          0
# 4      2564-03-04 07:55:40.703  2564-03-05 05:01:01.240          0
# ...                        ...                      ...        ...
# 52615  2565-03-14 14:31:31.910  2565-03-15 05:01:01.450          0
# 52616  2565-03-14 14:31:53.720  2565-03-15 05:01:01.450          0
# 52617  2565-03-05 12:36:33.263  2565-03-06 05:01:02.833          0
# 52618  2565-03-10 07:42:44.243  2565-03-11 05:01:01.390          0
# 52619  2565-03-15 13:28:12.177  2565-03-21 15:31:28.463          1
#
#        OutPatient  Emergency
# 0               1          0
# 1               1          0
# 2               1          0
# 3               1          0
# 4               1          0
# ...           ...        ...
# 52615           1          0
# 52616           1          0
# 52617           0          1
# 52618           1          0
# 52619           0          0
#
# [52620 rows x 13 columns]

# %%
a = table.drop(columns=['ENTY'])

# %%
a.to_excel('VisitDF.xlsx')
