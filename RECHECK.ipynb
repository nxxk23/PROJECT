# %% [markdown]
# <a href="https://colab.research.google.com/github/nxxk23/PROJECT/blob/main/RECHECK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
hemo = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Hemodialysis.csv', encoding='latin1')
lab = pd.read_csv('/content/drive/MyDrive/ckdresearch2023/Lab.csv')
patient_uid_list = hemo['PatientUID'].unique().tolist()
# Remove patient UIDs from lab['PatientUID'] that are not in the list
lab = lab[~lab['PatientUID'].isin(patient_uid_list)]
lab.shape
# Out:
# (17728574, 11)

# %% [markdown]
# **Create CountUniqueTable Again**

# %%
lab_location = lab['Location'].value_counts().reset_index()
lab_location.columns = ['Location', 'Location_Count']

lab_result = lab['ResultItemName'].value_counts().reset_index()
lab_result.columns = ['ResultItemName', 'ResultItemName_Count']

lab_request = lab['RequestItemName'].value_counts().reset_index()
lab_request.columns = ['RequestItemName', 'RequestItemName_Count']

columns_to_count = ['Location', 'ResultItemName', 'RequestItemName']

# Count unique values in the specified columns
lab_count = lab[columns_to_count].value_counts().reset_index()
lab_count.columns = ['Location', 'ResultItemName', 'RequestItemName', 'Count']

LabSummaryDF = pd.DataFrame(lab_count)

# %%
LabSummaryDF
# Out:
#                                        Location  \
# 0     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 2     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 3     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 4     ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# ...                                         ...
# 3348                     ห้อง Xray ชั้น 1-D1403
# 3349                     ห้อง Xray ชั้น 1-D1403
# 3350      ห้องปฏิบัติการหน่วยชีวโมเลกุลวินัจฉัย
# 3351      ห้องปฏิบัติการหน่วยชีวโมเลกุลวินัจฉัย
# 3352                           OPD Anest (SPAC)
#
#                                 ResultItemName  \
# 0                            CREATININE, 32202
# 1                       eGFR(CKD-EPI) age >=18
# 2                             POTASSIUM, 32103
# 3                                   BUN, 32201
# 4                           BICARBONATE, 32105
# ...                                        ...
# 3348                          Formatted Result
# ...

# %% [markdown]
# **Slope data**

# %%
import pandas as pd
slope = pd.read_excel('/content/drive/MyDrive/ckdresearch2023/Assign/SummaryFile/Slope.xlsx')

# %%
data = pd.DataFrame(slope)
data = data[['PatientUID','PatientVisitUID','Slopes']]

df = pd.DataFrame(data)

# Sorting the DataFrame by PatientUID and PatientVisitUID
df = df.sort_values(['PatientUID', 'PatientVisitUID'])

# Adding a NextSlope column
df['Slopes'] = df.groupby('PatientUID')['Slopes'].shift(-1)

data = df.dropna()
data
# Out:
#        PatientUID  PatientVisitUID     Slopes
# 0            2299          3386255  -7.158596
# 1            2299          4546471   5.550691
# 2            2299          5812902  -6.063710
# 3            2299          6947220 -12.812245
# 4            2299          8186767  28.287500
# ...           ...              ...        ...
# 73378     3319961          9270330  -4.256753
# 73380     3319971          9270331  -0.692078
# 73382     3320048          9242721   7.217875
# 73384     3320050          9257281 -32.794557
# 73388     3321289          9274735 -36.776371
#
# [52620 rows x 3 columns]

# %% [markdown]
# **Mapping**

# %%
lab_mapping = {
    'lab1': [1, 1587],
    'lab2': [3, 129, 185, 312],
    'lab3': [0, 103],
    'lab4': [5, 115],
    'lab5': [2, 112],
    'lab6': [6, 118],
    'lab7': [4, 117],
    'lab8': [63, 194],
    'lab9': [31, 172],
    'lab10': [33, 175],
    'lab11': [21, 137],
    'lab12': [22, 3001],
    'lab13': [8, 100, 1736, 2577, 2856, 2980],
    'lab14': [13],
    'lab15': [15],
    'lab16': [159],
    'lab17': [198, 238, 584],
    'lab18': [154],
    'lab19': [30, 156, 177, 223, 277, 561],
    'lab20': [49, 153],
    'lab21': [23, 114],
    'lab22': [50, 130],
    'lab23': [34, 126],
    'lab24': [51, 131],
    'lab25': [220, 304, 539, 2909],
    'lab26': [191, 253],
    'lab27': [163],
    'lab28': [108,397,73,305],
    'lab29': [176, 2796],
    'lab30': [218, 949],
    'lab31': [233, 1424],
    'lab32': [182, 473]
}

# %%
# Create new columns for labels
lab['LabelResult'] = ""
lab['LabelRequest'] = ""

# Iterate through the lab_mapping dictionary and update 'LabelResult' and 'LabelRequest' columns
for lab_name, indices in lab_mapping.items():
    result_item_names = LabSummaryDF[LabSummaryDF.index.isin(indices)]['ResultItemName'].tolist()
    request_item_names = LabSummaryDF[LabSummaryDF.index.isin(indices)]['RequestItemName'].tolist()
    lab.loc[lab['ResultItemName'].isin(result_item_names), 'LabelResult'] = lab_name
    lab.loc[lab['RequestItemName'].isin(request_item_names), 'LabelRequest'] = lab_name

# %% [markdown]
# **Remap**

# %%
lab.loc[(lab['LabelResult'] == 'lab1') & (lab['LabelRequest'] == 'lab3'), 'LabelRequest'] = 'lab1' #L1:eGFR
lab.loc[(lab['LabelResult'] == 'lab12') & (lab['LabelRequest'] == 'lab15'), 'LabelRequest'] = 'lab12' #L12:Hemoglobin
lab.loc[(lab['LabelResult'] == 'lab13') & (lab['LabelRequest'] == 'lab15'), 'LabelRequest'] = 'lab13' #L13:HCT
lab.loc[(lab['LabelResult'] == 'lab14') & (lab['LabelRequest'] == 'lab15'), 'LabelRequest'] = 'lab14' #L14:WBC

# %%
lab = lab[(lab['LabelResult'] != '') & (lab['LabelRequest'] != '')]
lab = lab[(lab['LabelResult'] == lab['LabelRequest'])]
lab
# Out:
#           LabNo  PatientUID  PatientVisitUID  \
# 1             1        2299          2024049
# 5             1        2299          2024049
# 6             1        2299          2024049
# 7             1        2299          2024049
# 8             1        2299          2024049
# ...         ...         ...              ...
# 21635863    213      822860          5140446
# 21635937    214      822860          5140446
# 21635938    214      822860          5140446
# 21635940    214      822860          5140446
# 21635941    214      822860          5140446
#
#                                            Location     RequestItemName  \
# 1         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร      ALBUMIN, 32403
# 5         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร          BUN, 32201
# 6         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร      CALCIUM, 32106
# 7         ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร  CHOLESTEROL, 32501
# ...

# %% [markdown]
# **เก็บ lab row แค่ visitid ที่มีอยู่ในไฟล์ slope**

# %%
visitid = data['PatientVisitUID'].unique().tolist()
len(visitid)
# Out:
# 52620

# %%
check = lab[lab['PatientVisitUID'].isin(visitid)]

# %%
check['DuplicateIndex'] = check.groupby(['PatientUID', 'PatientVisitUID']).cumcount() #สร้างคอลัมน์มาเพื่อดูว่ามีแถวที่ visit ซ้ำในการตรวจแลปเดียวกัน
# Out:
# <ipython-input-35-63f6db99a5e2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check['DuplicateIndex'] = check.groupby(['PatientUID', 'PatientVisitUID']).cumcount() #สร้างคอลัมน์มาเพื่อดูว่ามีแถวที่ visit ซ้ำในการตรวจแลปเดียวกัน

# %%
check
# Out:
#           LabNo  PatientUID  PatientVisitUID  \
# 245           1        2299          3386255
# 246           1        2299          3386255
# 247           1        2299          3386255
# 248           1        2299          3386255
# 249           1        2299          3386255
# ...         ...         ...              ...
# 21627888    158     1553938          3335765
# 21627889    158     1553938          3335765
# 21628141    159     1553938          3335765
# 21628142    159     1553938          3335765
# 21628143    159     1553938          3335765
#
#                                            Location RequestItemName  \
# 245       ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร             BUN
# 246       ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร     CHOLESTEROL
# 247       ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร      CREATININE
# 248       ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร      CREATININE
# 249       ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร           HDL-C
# ...

# %%
pivoted = check.pivot(index=['PatientUID', 'PatientVisitUID', 'DuplicateIndex'], columns='LabelResult', values='ResultValue').reset_index()
pivoted
# Out:
# LabelResult  PatientUID  PatientVisitUID  DuplicateIndex  lab1 lab10 lab11  \
# 0                  2299          3386255               0   NaN   NaN   NaN
# 1                  2299          3386255               1   NaN   NaN   NaN
# 2                  2299          3386255               2   NaN   NaN   NaN
# 3                  2299          3386255               3  71.7   NaN   NaN
# 4                  2299          3386255               4   NaN   NaN   NaN
# ...                 ...              ...             ...   ...   ...   ...
# 865474          3321289          9274735               7   NaN   NaN   NaN
# 865475          3321289          9274735               8   NaN   NaN   NaN
# 865476          3321289          9274735               9   NaN   NaN   NaN
# 865477          3321289          9274735              10   NaN   NaN   NaN
# 865478          3321289          9274735              11   NaN   NaN   NaN
#
# ...

# %%
import pandas as pd
from datetime import datetime, timedelta

# Sort the DataFrame by 'PatientVisitUID' and 'DuplicateIndex'
pivoted.sort_values(by=['PatientVisitUID', 'DuplicateIndex'], ascending=[True, True], inplace=True)

# Define a custom function to fill null values with the latest non-null values within the same 'PatientVisitUID'
def fill_null_with_latest(group):
    for col in range(1, 33):  # Assuming columns 'lab1' through 'lab32'
        col_name = f'lab{col}'
        group[col_name] = group[col_name].fillna(method='ffill').fillna(method='bfill')
    return group.tail(1)

# Apply the custom function to each 'PatientVisitUID' group
resultlab = pivoted.groupby('PatientVisitUID').apply(fill_null_with_latest).reset_index(drop=True)

# %%
pivoted[(pivoted['PatientVisitUID'] == 2705230) & ~pivoted['lab1'].isnull()]
# Out:
# LabelResult  PatientUID  PatientVisitUID  DuplicateIndex  lab1 lab10 lab11  \
# 103888           136689          2705230               7  53.3   NaN   NaN
# 103912           136689          2705230              31  45.5   NaN   NaN
# 103932           136689          2705230              51  41.9   NaN   NaN
#
# LabelResult lab12 lab13 lab14 lab15  ... lab3 lab30 lab31 lab32 lab4 lab5  \
# 103888        NaN   NaN   NaN   NaN  ...  NaN   NaN   NaN   NaN  NaN  NaN
# 103912        NaN   NaN   NaN   NaN  ...  NaN   NaN   NaN   NaN  NaN  NaN
# 103932        NaN   NaN   NaN   NaN  ...  NaN   NaN   NaN   NaN  NaN  NaN
#
# LabelResult lab6 lab7 lab8 lab9
# 103888       NaN  NaN  NaN  NaN
# 103912       NaN  NaN  NaN  NaN
# 103932       NaN  NaN  NaN  NaN
#
# [3 rows x 35 columns]

# %%
pivoted[(pivoted['PatientVisitUID'] == 2705230) & ~pivoted['lab10'].isnull()]
# Out:
# LabelResult  PatientUID  PatientVisitUID  DuplicateIndex lab1 lab10 lab11  \
# 103891           136689          2705230              10  NaN   3.5   NaN
# 103915           136689          2705230              34  NaN   3.3   NaN
# 103935           136689          2705230              54  NaN   3.1   NaN
# 103952           136689          2705230              71  NaN   3.3   NaN
# 103968           136689          2705230              87  NaN   3.4   NaN
# ...                 ...              ...             ...  ...   ...   ...
# 104653           136689          2705230             772  NaN   2.8   NaN
# 104662           136689          2705230             781  NaN   3.2   NaN
# 104671           136689          2705230             790  NaN   3.4   NaN
# 104680           136689          2705230             799  NaN   3.4   NaN
# 104687           136689          2705230             806  NaN   3.6   NaN
#
# LabelResult lab12 lab13 lab14 lab15  ... lab3 lab30 lab31 lab32 lab4 lab5  \
# ...

# %%
resultlab
# Out:
# LabelResult  PatientUID  PatientVisitUID  DuplicateIndex   lab1 lab10 lab11  \
# 0                136689          2705230             840   41.9   3.6   3.8
# 1                142339          3061805             753   52.6   3.8   3.8
# 2               1355105          3199774            1352  126.8   3.3   3.6
# 3                514974          3249012              20   43.4   4.1   4.1
# 4                478463          3258047             386   36.0   3.6   3.9
# ...                 ...              ...             ...    ...   ...   ...
# 52615            369580          9336612              13  64.12   NaN   4.6
# 52616           1130532          9339080               8  42.00   3.1   3.8
# 52617           1002508          9341881              12  42.88   NaN   3.7
# 52618            170289          9348665               1  56.93   NaN   NaN
# 52619           1063019          9348880              11  61.83   NaN   3.7
#
# ...

# %% [markdown]
# **check L31**

# %%
LabSummaryDF.loc[[233, 1424]] #lab31
# Out:
#                                        Location  \
# 233   ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 1424  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
#
#                       ResultItemName                 RequestItemName  Count
# 233   SODIUM IN URINE 24 HRS., 34002         SODIUM IN URINE 24 HRS.   3314
# 1424  SODIUM IN URINE 24 HRS., 34002  SODIUM IN URINE 24 HRS., 34002     24

# %%
lab.shape
# Out:
# (6184103, 13)

# %%
lab[lab['LabelResult']=='lab31'].shape #หมายความว่า แมปตรง
# Out:
# (3338, 13)

# %%
resultlab.shape #เก็บแค่ visitslope
# Out:
# (52620, 35)

# %%
check[check['LabelResult']=='lab31'].shape #หมายความว่ามี visitid แค่ 285 อันที่ถูกเติม ดังนั้น 52620-285 = 52335 ==> จน.ค่าสูญหายคอลัมน์ L31
# Out:
# (285, 14)

# %%
pivoted['lab31'].notnull().sum()
# Out:
# 285

# %%
resultlab['lab31'].notnull().sum()
# Out:
# 284

# %%
resultlab['lab31'].isnull().sum()
# Out:
# 52336

# %%
wt[['L31:UrineSodium (24hrs)']].isnull().sum() #WideTable L31
# Out:
# L31:UrineSodium (24hrs)    52336
# dtype: int64

# %% [markdown]
# **check L32**

# %%
LabSummaryDF.loc[[182, 473]] #lab32
# Out:
#                                       Location  \
# 182  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
# 473  ห้องปฏิบัติการเคมีคลินิก เวชศาสตร์ชันสูตร
#
#                             ResultItemName  \
# 182  TOTAL PROTEIN IN URINE 24 HRS., 34104
# 473  TOTAL PROTEIN IN URINE 24 HRS., 34104
#
#                            RequestItemName  Count
# 182         TOTAL PROTEIN IN URINE 24 HRS.   7130
# 473  TOTAL PROTEIN IN URINE 24 HRS., 34104    440

# %%
lab[lab['LabelResult']=='lab32'].shape #หมายความว่า แมปตรง
# Out:
# (7570, 13)

# %%
check[check['LabelResult']=='lab32'].shape
# Out:
# (689, 14)

# %%
pivoted['lab32'].notnull().sum() #หมายความว่ามี visitid แค่ 689 อันที่ถูกเติม ดังนั้น 52620-689 = 51931 ==> จน.ค่าสูญหายคอลัมน์ L32
# Out:
# 689

# %%
resultlab['lab32'].notnull().sum() #เพราะเราใช้ค่าล่าสุด ถ้าหากว่า visit นั้นมีการตรวจซ้ำ lab เดียวกัน ก็จะเอาค่าล่าสุด มันเลยทำให้ ค่าสูญหายมันลด nonnul ต้องเพิ่ม
# Out:
# 663

# %%
wt[['L32:UrineProtein (24hrs)']].isnull().sum()
# Out:
# L32:UrineProtein (24hrs)    52109
# dtype: int64

# %% [markdown]
# **WideTable**

# %%
import pandas as pd
wt = pd.read_excel('/content/drive/MyDrive/ckdresearch2023/Assign/SummaryFile/WideTable/WideTable.xlsx')
wt = wt.iloc[:, 1:]
wt.head()
# Out:
#    PatientUID  Recent_Creatinine  Recent_eGFR              Recent_Date  \
# 0      924852               2.63         15.8  2560-08-07 12:32:50.527
# 1      989278               2.03         32.3  2560-08-11 08:22:48.737
# 2     2103792               1.05         55.9  2560-08-14 14:38:44.150
# 3      953611               1.03         51.1  2560-08-15 02:05:01.323
# 4      488150               1.94         32.6  2560-08-15 09:18:43.240
#
#    PatientVisitUID     Slopes  G1M2:ARB  G3M1:Statin  G5M2:NSAIDs  \
# 0          3349148   2.754717         0           30            0
# 1          3348711 -46.720000         0            0            0
# 2          3369057  11.018868         0            0            0
# 3          3366405  17.222520         0            0            0
# 4          3356167 -79.002653         0            0            0
#
#    G1M5:Diuretic  ...  L27:UrineAlbumin/Cr ratio  L28:UrineProtein/Cr ratio  \
# ...

# %%
wt[['L2:BUN',
       'L3:Creatinine', 'L4:Sodium', 'L5:Potassium', 'L6:Chloride',
       'L7:Bicarbonate', 'L8:Uric', 'L9:Calcium', 'L10:Phosphorus',
       'L11:Albumin', 'L12:Hemoglobin', 'L13:Hematocrit', 'L15:Platelet',
       'L16:TIBC', 'L17:Tranferin SAT', 'L18:Ferritin', 'L19:Blood sugar',
       'L20:HbA1c', 'L21:Cholesterol', 'L22:Triglyceride',
       'L23:LDL Cholesterol', 'L24:HDL Cholesterol', 'L25:Parathyroid hormone',
       'L26:Vitamin D', 'L27:UrineAlbumin/Cr ratio',
       'L28:UrineProtein/Cr ratio', 'L29:UrineVolume (24hrs)',
       'L30:UrineUrea (24hrs)', 'L31:UrineSodium (24hrs)',
       'L32:UrineProtein (24hrs)', 'L1:eGFR', 'L14:WBC']].isnull().sum()
# Out:
# L2:BUN                       12840
# L3:Creatinine                    1
# L4:Sodium                    21283
# L5:Potassium                 19019
# L6:Chloride                  21364
# L7:Bicarbonate               21204
# L8:Uric                      38898
# L9:Calcium                   40444
# L10:Phosphorus               40779
# L11:Albumin                  29910
# L12:Hemoglobin               23612
# L13:Hematocrit               22310
# L15:Platelet                 22314
# L16:TIBC                     51736
# L17:Tranferin SAT            51851
# L18:Ferritin                 51725
# L19:Blood sugar              23302
# L20:HbA1c                    27985
# L21:Cholesterol              18974
# L22:Triglyceride             26220
# L23:LDL Cholesterol          23395
# L24:HDL Cholesterol          26626
# L25:Parathyroid hormone      51737
# L26:Vitamin D                51350
# L27:UrineAlbumin/Cr ratio    51316
# L28:UrineProtein/Cr ratio    47151
# L29:UrineVolume (24hrs)      52280
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

null_df = wt.isnull()
null_count = null_df.sum()
null_count_sorted = null_count.sort_values()
plt.figure(figsize=(10, 15))  # Adjust the figsize to control the plot size
ax = null_count_sorted.plot(kind='barh', color='skyblue', edgecolor='none')  # Use 'barh' for horizontal bars
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)

plt.title('Columns with Null Values and Their Counts')
plt.xlabel('Number of Null Values')
plt.ylabel('Columns')
plt.tight_layout()
label_distance = 10
for i, v in enumerate(null_count_sorted):
    ax.text(v + label_distance, i, str(v), color='black', va='center')

plt.show()

# %%
wide_table.isnull().sum()

# %% [markdown]
# #**Vital Sign**
